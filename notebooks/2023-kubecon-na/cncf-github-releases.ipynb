# %% [markdown]
# # Fetch all GitHub Release info for CNCF projects

# %%
# graphviz - suffers from a bug --> https://github.com/ContinuumIO/anaconda-issues/issues/485
# %pip list | grep -E 'pandas|dask|sqlalchemy|psycopg2-binary|PyGitHub|python-dotenv|jsonpath-ng'
# %pip install pandas dask sqlalchemy psycopg2-binary PyGitHub python-dotenv jsonpath-ng
# Out:
# dask                               2023.10.1
# dask_labextension                  7.0.0
# jsonpath-ng                        1.6.0
# pandas                             2.0.3
# psycopg2-binary                    2.9.9
# python-dotenv                      1.0.0
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: dask in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (2023.10.1)
# Requirement already satisfied: sqlalchemy in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (2.0.23)
# Requirement already satisfied: psycopg2-binary in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (2.9.9)
# Requirement already satisfied: PyGitHub in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: python-dotenv in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: jsonpath-ng in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: click>=8.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from dask) (6.8.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: pynacl>=1.4.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from PyGitHub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from PyGitHub) (2.31.0)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from PyGitHub) (2.8.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from PyGitHub) (1.26.18)
# Requirement already satisfied: Deprecated in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from PyGitHub) (1.2.14)
# Requirement already satisfied: ply in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from jsonpath-ng) (3.11)
# Requirement already satisfied: zipp>=0.5 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: locket in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->PyGitHub) (41.0.5)
# Requirement already satisfied: cffi>=1.4.1 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from pynacl>=1.4.0->PyGitHub) (1.16.0)
# Requirement already satisfied: six>=1.5 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (2023.7.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from Deprecated->PyGitHub) (1.15.0)
# Requirement already satisfied: pycparser in /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGitHub) (2.21)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list installed -v
# Out:
# Package                            Version      Location                                                                Installer
# ---------------------------------- ------------ ----------------------------------------------------------------------- ---------
# aiohttp                            3.8.6        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# aiohttp-retry                      2.8.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# aiosignal                          1.3.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# altair                             5.1.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# annotated-types                    0.6.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# anyio                              4.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# appnope                            0.1.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# argon2-cffi                        23.1.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# argon2-cffi-bindings               21.2.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# arrow                              1.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# asttokens                          2.4.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# async-lru                          2.0.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# async-timeout                      4.0.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# attrs                              23.1.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Babel                              2.13.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# backoff                            2.2.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# beautifulsoup4                     4.12.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# bleach                             6.1.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# bokeh                              3.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# botocore                           1.31.79      /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# bqplot                             0.12.42      /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# certifi                            2023.7.22    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# cffi                               1.16.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# charset-normalizer                 3.3.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# click                              8.1.7        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# cloudpickle                        3.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# comm                               0.2.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# contourpy                          1.2.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# cryptography                       41.0.5       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# cycler                             0.12.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# dask                               2023.10.1    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# dask_labextension                  7.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# debugpy                            1.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# decorator                          5.1.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# defusedxml                         0.7.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Deprecated                         1.2.14       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# distributed                        2023.10.1    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# docstring-to-markdown              0.13         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# executing                          2.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# fastjsonschema                     2.18.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# fonttools                          4.44.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# fqdn                               1.5.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# frozenlist                         1.4.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# fsspec                             2023.10.0    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# gast                               0.4.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# gql                                3.4.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# graphql-core                       3.2.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# greenlet                           3.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# idna                               3.4          /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# importlib-metadata                 6.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# inflect                            7.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ipycytoscape                       1.3.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ipydatagrid                        1.2.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ipykernel                          6.26.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ipython                            8.17.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ipywidgets                         8.1.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# isoduration                        20.11.0      /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# isort                              5.12.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jedi                               0.19.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Jinja2                             3.1.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jmespath                           1.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jp                                 0.2.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jq                                 1.6.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# json5                              0.9.14       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jsonpath-ng                        1.6.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jsonpointer                        2.4          /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jsonschema                         4.19.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jsonschema-specifications          2023.7.1     /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter_client                     8.6.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter_core                       5.5.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter-events                     0.9.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter-lsp                        2.2.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter-resource-usage             1.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter_server                     2.10.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter_server_proxy               4.1.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyter_server_terminals           0.4.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab                         4.0.8        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab_favorites               3.2.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab-pygments                0.2.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab_recents                 3.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab_server                  2.25.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab-spellchecker            0.8.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab-visualpython            3.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterlab-widgets                 3.0.9        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupyterthemes                      0.20.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# jupytext                           1.15.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# kiwisolver                         1.4.5        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# lesscpy                            0.15.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# locket                             1.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# lz4                                4.3.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# markdown-it-py                     3.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# MarkupSafe                         2.1.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# matplotlib                         3.8.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# matplotlib-inline                  0.1.6        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# mdit-py-plugins                    0.4.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# mdurl                              0.1.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# mistune                            3.0.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# msgpack                            1.0.7        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# multidict                          6.0.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# mypy                               1.6.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# mypy-extensions                    1.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# nbclient                           0.7.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# nbconvert                          7.11.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# nbformat                           5.9.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# nest-asyncio                       1.5.8        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# notebook                           7.0.6        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# notebook_shim                      0.2.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# numpy                              1.26.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# opentelemetry-api                  1.20.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# opentelemetry-sdk                  1.20.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# opentelemetry-semantic-conventions 0.41b0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# overrides                          7.4.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# packaging                          23.2         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pandas                             2.0.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pandocfilters                      1.5.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# parso                              0.8.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# partd                              1.4.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pexpect                            4.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Pillow                             10.1.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pip                                23.2.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# platformdirs                       3.11.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# plotly                             5.18.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pluggy                             1.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ply                                3.11         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# prometheus-client                  0.18.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# prompt-toolkit                     3.0.39       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# psutil                             5.9.6        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# psycopg2-binary                    2.9.9        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ptyprocess                         0.7.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pure-eval                          0.2.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# py2vega                            0.6.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pyarrow                            14.0.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pycodestyle                        2.11.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pycparser                          2.21         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pydantic                           2.4.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pydantic_core                      2.10.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# PyGithub                           2.1.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Pygments                           2.16.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# PyJWT                              2.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pyls-isort                         0.2.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pylsp-mypy                         0.6.7        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pylsp-rope                         0.1.11       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# PyNaCl                             1.5.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pyparsing                          3.1.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# python-dateutil                    2.8.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# python-dotenv                      1.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# python-json-logger                 2.0.7        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# python-lsp-jsonrpc                 1.1.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# python-lsp-server                  1.8.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pytoolconfig                       1.2.6        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pytz                               2023.3.post1 /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# PyYAML                             6.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# pyzmq                              25.1.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# referencing                        0.30.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# requests                           2.31.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# requests-toolbelt                  0.10.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# rfc3339-validator                  0.1.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# rfc3986-validator                  0.1.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# rope                               1.11.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# rpds-py                            0.12.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# Send2Trash                         1.8.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# setuptools                         65.5.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# simpervisor                        1.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# six                                1.16.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# sniffio                            1.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# sortedcontainers                   2.4.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# soupsieve                          2.5          /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# spectate                           1.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# sqlacodegen-v2                     0.1.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# SQLAlchemy                         2.0.23       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# stack-data                         0.6.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tabulate                           0.9.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tblib                              3.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tenacity                           8.2.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# terminado                          0.17.1       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tinycss2                           1.2.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# toml                               0.10.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tomli                              2.0.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# toolz                              0.12.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tornado                            6.3.3        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# traitlets                          5.13.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# traittypes                         0.2.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# types-python-dateutil              2.8.19.14    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# typing_extensions                  4.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# tzdata                             2023.3       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# ujson                              5.8.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# uri-template                       1.3.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# urllib3                            1.26.18      /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# voila                              0.5.5        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# wcwidth                            0.2.9        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# webcolors                          1.13         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# webencodings                       0.5.1        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# websocket-client                   1.6.4        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# websockets                         10.4         /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# wget                               3.2          /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# whatthepatch                       1.0.5        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# widgetsnbextension                 4.0.9        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# wrapt                              1.15.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# xyzservices                        2023.10.1    /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# yapf                               0.40.2       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# yarl                               1.9.2        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# zict                               3.0.0        /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
# zipp                               3.17.0       /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages pip
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display, HTML

import os
import pandas as pd
import dask
import dask.dataframe as dd

from typing import Any

import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def safe_set_index(df: pd.DataFrame, idx_wanted: list[str]) -> pd.DataFrame:

    # check to see if the index is already set, else, data loss as set_index can be destructive
    idx_existing = list(df.index.names)

    if idx_wanted == idx_existing:
        print(f'\n*** WARNING: attempt to set index to what it already is thwarted! \n')
    else:
        df.set_index(idx_wanted, verify_integrity=True, inplace=True) # note: index must be unique!
        df.sort_index(inplace=True)
    return df

def split_org_repo(df:      pd.DataFrame, 
                   colname: str,
                   drop:    bool = False,
                   newcol_org_name:  str = 'org_name',
                   newcol_repo_name: str = 'repo_name') -> pd.DataFrame:
    '''split_org_repo(df, colname) - org_name/repo_name --> org_name, repo_name'''
    
    if colname is None:
        raise ValueError('split_org_repo: missing colname!')

    # https://swdevnotes.com/python/2022/extract-data-from-json-in-pandas-dataframe/
    
    # expand=True returns a dataframe  which we can rename columns on
    df_newcols = df[colname].copy().str.split(pat='/', n=1, expand=True)

    df_newcols.rename(columns={0: newcol_org_name, 1: newcol_repo_name}, inplace=True)

    if drop:
        df.drop(colname, axis=1, inplace=True)

    df = pd.concat([df,df_newcols], axis=1)
    return df

#############

def load_repos(fname: str=None, 
               splitcols: bool=False) -> pd.DataFrame:
    '''Load repos from a file'''

    with open(fname, 'r') as f:
        df = pd.DataFrame(f.readlines(), columns=['name'])

    # strip comments (note '~' negation in selector)
    df = df[~df['name'].astype(str).str.startswith('#')]

    # the universe is inperfect, as is input data
    df.name = df.name.str.rstrip(to_strip='\n')
    df.name = df.name.str.rstrip(to_strip='/')

    # {name: someOrg/someRepo} --> { name: 'someOrg/someRepo', org_name = 'someOrg', repo_name = 'someRepo'
    if splitcols:
        df = split_org_repo(df, colname='name')
    return df

# %%
from dask.distributed import Client

client = Client(n_workers=4)
client
# Out:
# /Users/me/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 60084 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:60085' processes=4 threads=16, memory=64.00 GiB>

# %%
# https://landscape.cncf.io/data/items.json
LANDSCAPE_FNAME = '../../landscape-items.json'

# repo_urls = [f'https://github.com/{org_repo}' for org_repo in osrb.name]
# repo_urls[:5]

use_dask = False


if use_dask:
    ddf = dd.read_json(LANDSCAPE_FNAME, orient='records', blocksize="2MB")
    ddf.compute()
    display(ddf.visualize())
    display(ddf.head())
else:
    df = pd.read_json(LANDSCAPE_FNAME, orient='records')
    display(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     display(ddf.head())
#      <a href='vscode-notebook-cell:/Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a> else:
# ---> <a href='vscode-notebook-cell:/Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     df = pd.read_json(LANDSCAPE_FNAME, orient='records')
#      <a href='vscode-notebook-cell:/Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a>     display(df.head())
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/pandas/io/json/_json.py:784, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782     return json_reader
#     783 else:
# --> 784     return json_reader.read()
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/pandas/io/json/_json.py:975, in JsonReader.read(self)
#     973         obj = self._get_object_parser(self._combine_lines(data_lines))
#     974 else:
# --> 975     obj = self._get_object_parser(self.data)
#     976 if self.dtype_backend is not lib.no_default:
#     977     return obj.convert_dtypes(
#     978         infer_objects=False, dtype_backend=self.dtype_backend
#     979     )
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/pandas/io/json/_json.py:1001, in JsonReader._get_object_parser(self, json)
#     999 obj = None
#    1000 if typ == "frame":
# -> 1001     obj = FrameParser(json, **kwargs).parse()
#    1003 if typ == "series" or obj is None:
#    1004     if not isinstance(dtype, bool):
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/pandas/io/json/_json.py:1134, in Parser.parse(self)
#    1133 def parse(self):
# -> 1134     self._parse()
#    1136     if self.obj is None:
#    1137         return None
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/pandas/io/json/_json.py:1347, in FrameParser._parse(self)
#    1344     self.obj = parse_table_schema(json, precise_float=self.precise_float)
#    1345 else:
#    1346     self.obj = DataFrame(
# -> 1347         loads(json, precise_float=self.precise_float), dtype=None
#    1348     )
#
# ValueError: Expected object or value

# %%
df.info(memory_usage='deep')
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 2077 entries, 0 to 2076
# dtypes: string(2077)
# memory usage: 8.9 MB

# %%
ddf.transpose().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/me/gh/cncf/landscape-graph/notebooks/2023-kubecon-na/cncf-github-releases.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> ddf.transpose().head()
#
# File ~/gh/cncf/landscape-graph/.venv-nb/lib/python3.11/site-packages/dask/dataframe/core.py:5136, in DataFrame.__getattr__(self, key)
#    5134     object.__getattribute__(self, key)
#    5135 else:
# -> 5136     raise AttributeError("'DataFrame' object has no attribute %r" % key)
#
# AttributeError: 'DataFrame' object has no attribute 'transpose'

# %% [markdown]
# ## Fetch project release data from GitHub API

# %%
import time
import os
import json
import pandas as pd
from typing import List
from datetime import datetime, timezone
from github import Github, GithubException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

def fetch_repo_data(token: str, 
                    repo_list: List[str], 
                    since: datetime=None, 
                    json_file: str=None, 
                    csv_file: str=None, 
                    state_file: str=None) -> pd.DataFrame:

    # Initialize DataFrame
    df = pd.DataFrame(columns=[
        'repo_name', 'release_name', 'release_date', 
        'language', 'release_notes'
    ])

    # Initialize GitHub client
    g = Github(token)

    # Initialize loop state
    if state_file:
        try:
            with open(state_file, 'r') as f:
                state = json.load(f)
        except FileNotFoundError:
            state = {'i': 0, 'repos_done': []}
    else:
        state = {'i': 0, 'repos_done': []}

    while state['i'] < len(repo_list):
        repo_str = repo_list[state['i']]

        # Skip repository if already done
        if repo_str in state['repos_done']:
            print(f"Skipping {repo_str}")
            state['i'] += 1
            continue

        # Get repository
        while True:
            try:
                repo = g.get_repo(repo_str)
                break
            except GithubException as e:
                if e.status == 404:
                    print(f"Repository {repo_str} not found")
                    break
                elif e.status == 429:
                    print(f"Rate limit exceeded, waiting for {e.headers['Retry-After']} seconds...")
                    time.sleep(int(e.headers['Retry-After']))
                else:
                    print(f"Error getting repository {repo_str}: {e}")
                    break

        if not repo:
            state['i'] += 1
            continue

        # Get all releases
        releases = repo.get_releases()
        language = repo.language

        for release in releases:
            if since is None or release.created_at >= since:
                df = pd.concat([df, pd.DataFrame({
                    'repo_name': [repo_str],
                    'release_name': [release.title],
                    'release_date': [str(release.published_at)],
                    'language': [language],
                    'release_notes': [release.body]
                })])
                print(f"Added {release.published_at}, {repo_str}::{release.title}  ")

        # Save state
        if state_file:
            state['repos_done'].append(repo_str)
            with open(state_file, 'w') as f:
                json.dump(state, f, indent=4)

        state['i'] += 1

    print (releases)
    
    # Save as CSV
    if csv_file:
        df.to_csv(csv_file, index=False)

    # Save as JSON
    if json_file:
        df.to_json(json_file, orient='records', lines=True)
    return df

# %%
# Example usage
token = os.environ['GITHUB_TOKEN']
repos = osrb.name
since_date = datetime(2023, 1, 1, tzinfo=timezone.utc)
json_file = "out/osrb-github-releases.json"
csv_file = "out/osrb-github-releases.csv"
state_file = "out/osrb-github-releases.state.json"

releases = fetch_repo_data(token, 
                           repos, 
                           since=since_date, 
                           json_file=json_file, 
                           csv_file=csv_file, 
                           state_file=state_file)
releases

# %% [markdown]
# ## Visualize Releases

# %%
# %pip install ipympl

# %matplotlib inline
# %matplotlib widget

# %%
import plotly.express as px
import matplotlib.pyplot as plt

def plot_releases_timeline(releases: pd.DataFrame):
    fig = px.timeline(releases, x_start="release_date", x_end="release_date", y="repo_name", color="language", title="GitHub Releases Timeline")
    fig.update_yaxes(autorange="reversed")
    fig.show()

def plot_releases_scatter_simple(releases: pd.DataFrame):
    # Filter releases by year
    releases_2023 = releases[releases['release_date'].dt.year == 2023]

    # Create scatter plot
    fig = px.scatter(releases_2023, x="release_date", y="repo_name", color="language", title="GitHub Releases Scatter Plot")
    fig.update_yaxes(autorange="reversed")
    fig.show()

def plot_releases_scatter(releases: pd.DataFrame):
    # Filter releases by year
    releases_2023 = releases[releases['release_date'].dt.year == 2023]

    # Group releases by organization
    releases_2023['organization'] = releases_2023['repo_name'].apply(lambda x: x.split('/')[0])

    # Create scatter plot
    fig = px.scatter(releases_2023, x="release_date", y="repo_name", color="organization", symbol="language", title="GitHub Releases Scatter Plot")
    fig.update_yaxes(autorange="reversed")
    
    fig.update_layout(showlegend=True,
                      autosize=True,
                      width=1000,
                      height=2500,
                      ),
    fig.show()

# %%
import pandas as pd
import os

debug_releases = releases.copy()
    
# Load releases data from CSV file
csv_file = "out/releases.csv"
if os.path.exists(csv_file):
    releases = pd.read_csv(csv_file)
else:
    print(f"CSV file {csv_file} not found")

releases.release_date = pd.to_datetime(releases.release_date)

plot_releases_scatter(releases)

# %%
releases_by_repo = releases[['repo_name', 'release_date']].groupby('repo_name').count()
releases_by_repo
