# %% [markdown]
# # Fetch all cncf/landscape current full info (items.json)

# %%
#!wget https://landscape.cncf.io/data/items.json

# %%
# %%bash
# # array of JSON --> JSONL
# jq  -c '.[]' items.json > items.jsonl
#
# ls -lahF items.jsonl && wc -l items.jsonl

# %%
# %%bash
# # landscape | select(CNCF Projects) --> cncf-projects.jsonl
# jq -c 'select(.relation == "graduated" or .relation == "incubating" or .relation == "sandbox")' items.jsonl > cncf-projects.jsonl
#
# ls -lahF cncf-projects.jsonl
# wc -l cncf-projects.jsonl
# Out:
# -rw-r--r--  1 me  staff   9.7M Nov  8 03:37 items.jsonl
#     2267 items.jsonl
# -rw-r--r--  1 me  staff   3.9M Nov  8 03:37 cncf-projects.jsonl
#      178 cncf-projects.jsonl

# %%
# %%bash
# # create list of urls
# jq -c '.repo_url' cncf-projects.jsonl | tee repos.txt
#
# ls -lahF cncf-projects.jsonl
# wc -l cncf-projects.jsonl
# Out:
# -rw-r--r--  1 me  staff   9.7M Nov  8 03:37 items.jsonl
#     2267 items.jsonl
# -rw-r--r--  1 me  staff   3.9M Nov  8 03:37 cncf-projects.jsonl
#      178 cncf-projects.jsonl

# %%
# for PAT / token
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## helpers

# %%
import pandas as pd

pd.set_option('display.max_rows', 512)
pd.set_option('display.max_columns', 512)
pd.set_option('display.width', 512)

def safe_set_index(df:         pd.DataFrame, 
                   idx_wanted: list[str]) -> pd.DataFrame:

    # check to see if the index is already set, else, data loss as set_index can be destructive
    idx_existing = list(df.index.names)

    if idx_wanted == idx_existing:
        print(f'\n*** WARNING: attempt to set index to what it already is thwarted! \n')
    else:
        df.set_index(idx_wanted, verify_integrity=True, inplace=True) # note: index must be unique!
        df.sort_index(inplace=True)
    return df

def split_org_repo(df:      pd.DataFrame, 
                   colname: str,
                   drop:    bool = False,
                   newcol_org_name:  str = 'org_name',
                   newcol_repo_name: str = 'repo_name') -> pd.DataFrame:
    '''split_org_repo(df, colname) - org_name/repo_name --> org_name, repo_named'''
    
    if colname is None:
        raise ValueError('split_org_repo: missing colname!')

    # df['tmp'] = df[colname].copy()
    # df_newcols = df['tmp'].str.split(pat='/', n=1, expand=True)

    # https://swdevnotes.com/python/2022/extract-data-from-json-in-pandas-dataframe/
    # expand=True returns a dataframe  which we can rename columns on
    
    df_newcols = df[colname].copy().str.split(pat='/', n=1, expand=True)
    df_newcols.rename(columns={0: newcol_org_name, 1: newcol_repo_name}, inplace=True)

    if drop:
        df.drop(colname, axis=1, inplace=True)

    df = pd.concat([df,df_newcols], axis=1)
    return df

# %% [markdown]
# ## Load the Landscape

# %%
import os
import pandas as pd

file_path = './cncf-projects.jsonl'

if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
    df = pd.read_json(file_path, lines=True)
else:
    print(f"File {file_path} does not exist or is empty.")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 55 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      178 non-null    object
#  1   homepage_url              178 non-null    object
#  2   project                   178 non-null    object
#  3   repo_url                  176 non-null    object
#  4   logo                      178 non-null    object
#  5   twitter                   174 non-null    object
#  6   crunchbase                178 non-null    object
#  7   extra                     176 non-null    object
#  8   github_data               176 non-null    object
#  9   repos                     176 non-null    object
#  10  github_start_commit_data  176 non-null    object
#  11  image_data                178 non-null    object
#  12  firstCommitDate           176 non-null    object
#  13  firstCommitLink           176 non-null    object
#  14  latestCommitDate          176 non-null    object
#  15  latestCommitLink          176 non-null    object
#  16  releaseDate               165 non-null    object
#  17  releaseLink               165 non-null    object
#  18  commitsThisYear           178 non-null    int64
#  19  contributorsCount         176 non-null    float64
#  20  contributorsLink          176 non-null    object
#  21  language                  174 non-null    object
#  22  stars                     176 non-null    float64
#  23  license                   178 non-null    object
#  24  headquarters              178 non-null    object
#  25  latestTweetDate           167 non-null    object
#  26  description               178 non-null    object
#  27  organization              178 non-null    object
#  28  crunchbaseData            178 non-null    object
#  29  path                      178 non-null    object
#  30  landscape                 178 non-null    object
#  31  category                  178 non-null    object
#  32  amountKind                174 non-null    object
#  33  amount                    178 non-null    object
#  34  oss                       178 non-null    bool
#  35  href                      178 non-null    object
#  36  bestPracticeBadgeId       178 non-null    int64
#  37  bestPracticePercentage    125 non-null    float64
#  38  industries                178 non-null    object
#  39  starsPresent              178 non-null    bool
#  40  starsAsText               178 non-null    object
#  41  marketCapPresent          178 non-null    bool
#  42  marketCapAsText           178 non-null    object
#  43  id                        178 non-null    object
#  44  flatName                  178 non-null    object
#  45  member                    178 non-null    object
#  46  relation                  178 non-null    object
#  47  isSubsidiaryProject       178 non-null    bool
#  48  allow_duplicate_repo      28 non-null     float64
#  49  project_org               7 non-null      object
#  50  joined                    2 non-null      object
#  51  enduser                   1 non-null      float64
#  52  url_for_bestpractices     4 non-null      object
#  53  open_source               1 non-null      float64
#  54  second_path               1 non-null      object
# dtypes: bool(4), float64(6), int64(2), object(43)
# memory usage: 71.7+ KB
# None

# %%
df.head(1)
# Out:
#    name          homepage_url  project                              repo_url      logo                          twitter                                         crunchbase                                              extra                                        github_data                                              repos                           github_start_commit_data                                         image_data       firstCommitDate                                    firstCommitLink  \
# 0  Akri  https://docs.akri.sh  sandbox  https://github.com/project-akri/akri  akri.svg  https://twitter.com/ProjectAkri  https://www.crunchbase.com/organization/cloud-...  {'accepted': '2021-09-14', 'annual_review_date...  {'languages': [{'name': 'Rust', 'value': 10535...  [{'url': 'https://github.com/project-akri/akri...  {'start_commit_link': '/project-akri/akri/comm...  {'fileName': 'akri.svg', 'hash': '2nK42JQaM8qF...  2020-10-14T00:42:19Z  https://github.com/project-akri/akri/commit/94...
#
#                                     latestCommitDate                                   latestCommitLink                                        releaseDate                                    releaseLink  commitsThisYear  contributorsCount                                   contributorsLink language  stars             license               headquarters                                    latestTweetDate                                   description                              organization  \
# 0  {'text': '2 months ago', 'value': '950', 'orig...  https://github.com/project-akri/akri/commit/98...  {'text': '7 months ago', 'value': '900', 'orig...  https://github.com/project-akri/akri/releases              197               34.0  https://github.com/project-akri/akri/graphs/co...     Rust  996.0  Apache License 2.0  San Francisco, California  {'text': '7 months ago', 'value': '900', 'orig...  A Kubernetes Resource Interface for the Edge  Cloud Native Computing Foundation (CNCF)
#
#                                       crunchbaseData                                       path                                  landscape      category amountKind   amount   oss            href  bestPracticeBadgeId  bestPracticePercentage                                         industries  starsPresent starsAsText  marketCapPresent marketCapAsText    id flatName member relation  isSubsidiaryProject  allow_duplicate_repo project_org joined  enduser url_for_bestpractices  open_source second_path
# 0  {'name': 'Cloud Native Computing Foundation (C...  Provisioning / Automation & Configuration  Provisioning / Automation & Configuration  Provisioning    funding  3000000  True  logos/akri.svg                 5339                    99.0  [Cloud Computing, Cloud Infrastructure, Non Pr...          True         996              True             $3M  akri     Akri  False  sandbox                False                   NaN         NaN    NaN      NaN                   NaN          NaN         NaN

# %%
# df_landscape = safe_set_index(df, idx_wanted=['relation','category','name'])
# df_landscape

# %%
# df2=df[['B','D','F']].rename({'B':'X','D':'Y','F':'Z'}, axis=1)

df_tiny=df[['relation', 
            'category', 
            'path', 
            'name',
            'repo_url']].copy()

df_tiny['repo'] = df_tiny['repo_url'].astype('string').str.removeprefix('https://github.com/')
df_tiny = split_org_repo(df_tiny, 'repo').dropna()
df_tiny.head(20)
# Out:
#       relation      category                                       path                        name                                           repo_url                              repo                 org_name           repo_name
# 0      sandbox  Provisioning  Provisioning / Automation & Configuration                        Akri               https://github.com/project-akri/akri                 project-akri/akri             project-akri                akri
# 1      sandbox  Provisioning  Provisioning / Automation & Configuration  CDK for Kubernetes (CDK8s)                https://github.com/cdk8s-team/cdk8s                  cdk8s-team/cdk8s               cdk8s-team               cdk8s
# 2   incubating  Provisioning  Provisioning / Automation & Configuration             Cloud Custodian  https://github.com/cloud-custodian/cloud-custo...   cloud-custodian/cloud-custodian          cloud-custodian     cloud-custodian
# 3      sandbox  Provisioning  Provisioning / Automation & Configuration                   DevStream          https://github.com/devstream-io/devstream            devstream-io/devstream             devstream-io           devstream
# 4      sandbox  Provisioning  Provisioning / Automation & Configuration                         KCL                    https://github.com/kcl-lang/kcl                      kcl-lang/kcl                 kcl-lang                 kcl
# 5      sandbox  Provisioning  Provisioning / Automation & Configuration                         kpt        https://github.com/GoogleContainerTools/kpt          GoogleContainerTools/kpt     GoogleContainerTools                 kpt
# 6      sandbox  Provisioning  Provisioning / Automation & Configuration                      KubeDL                https://github.com/kubedl-io/kubedl                  kubedl-io/kubedl                kubedl-io              kubedl
# 7   incubating  Provisioning  Provisioning / Automation & Configuration                    KubeEdge               https://github.com/kubeedge/kubeedge                 kubeedge/kubeedge                 kubeedge            kubeedge
# 8      sandbox  Provisioning  Provisioning / Automation & Configuration                     Meshery                 https://github.com/meshery/meshery                   meshery/meshery                  meshery             meshery
# 9      sandbox  Provisioning  Provisioning / Automation & Configuration                      Metal³    https://github.com/metal3-io/baremetal-operator      metal3-io/baremetal-operator                metal3-io  baremetal-operator
# 10     sandbox  Provisioning  Provisioning / Automation & Configuration                    OpenYurt             https://github.com/openyurtio/openyurt               openyurtio/openyurt               openyurtio            openyurt
# 11     sandbox  Provisioning  Provisioning / Automation & Configuration                   SuperEdge             https://github.com/superedge/superedge               superedge/superedge                superedge           superedge
# 12     sandbox  Provisioning  Provisioning / Automation & Configuration                  Tinkerbell                 https://github.com/tinkerbell/tink                   tinkerbell/tink               tinkerbell                tink
# 13     sandbox  Provisioning          Provisioning / Container Registry                Distribution       https://github.com/distribution/distribution         distribution/distribution             distribution        distribution
# 14  incubating  Provisioning          Provisioning / Container Registry                   Dragonfly         https://github.com/dragonflyoss/Dragonfly2           dragonflyoss/Dragonfly2             dragonflyoss          Dragonfly2
# 15   graduated  Provisioning          Provisioning / Container Registry                      Harbor                 https://github.com/goharbor/harbor                   goharbor/harbor                 goharbor              harbor
# 16     sandbox  Provisioning          Provisioning / Container Registry                         zot                 https://github.com/project-zot/zot                   project-zot/zot              project-zot                 zot
# 17  incubating  Provisioning       Provisioning / Security & Compliance                cert-manager       https://github.com/cert-manager/cert-manager         cert-manager/cert-manager             cert-manager        cert-manager
# 18     sandbox  Provisioning       Provisioning / Security & Compliance     Confidential Containers  https://github.com/confidential-containers/ope...  confidential-containers/operator  confidential-containers            operator
# 19     sandbox  Provisioning       Provisioning / Security & Compliance                ContainerSSH       https://github.com/containerssh/containerssh         containerssh/containerssh             containerssh        containerssh

# %%
cats = df_tiny['category'].drop_duplicates().tolist()
cats
# Out:
# ['Provisioning',
#  'Runtime',
#  'Orchestration & Management',
#  'App Definition and Development',
#  'Platform',
#  'Serverless',
#  'Observability and Analysis',
#  'Wasm']

# %%
# Visual Python: Data Analysis > Data Info
display(df_tiny)
# Out:
#        relation                        category                                               path                                 name                                           repo_url                                               repo                    org_name                 repo_name
# 0       sandbox                    Provisioning          Provisioning / Automation & Configuration                                 Akri               https://github.com/project-akri/akri                                  project-akri/akri                project-akri                      akri
# 1       sandbox                    Provisioning          Provisioning / Automation & Configuration           CDK for Kubernetes (CDK8s)                https://github.com/cdk8s-team/cdk8s                                   cdk8s-team/cdk8s                  cdk8s-team                     cdk8s
# 2    incubating                    Provisioning          Provisioning / Automation & Configuration                      Cloud Custodian  https://github.com/cloud-custodian/cloud-custo...                    cloud-custodian/cloud-custodian             cloud-custodian           cloud-custodian
# 3       sandbox                    Provisioning          Provisioning / Automation & Configuration                            DevStream          https://github.com/devstream-io/devstream                             devstream-io/devstream                devstream-io                 devstream
# 4       sandbox                    Provisioning          Provisioning / Automation & Configuration                                  KCL                    https://github.com/kcl-lang/kcl                                       kcl-lang/kcl                    kcl-lang                       kcl
# 5       sandbox                    Provisioning          Provisioning / Automation & Configuration                                  kpt        https://github.com/GoogleContainerTools/kpt                           GoogleContainerTools/kpt        GoogleContainerTools                       kpt
# 6       sandbox                    Provisioning          Provisioning / Automation & Configuration                               KubeDL                https://github.com/kubedl-io/kubedl                                   kubedl-io/kubedl                   kubedl-io                    kubedl
# 7    incubating                    Provisioning          Provisioning / Automation & Configuration                             KubeEdge               https://github.com/kubeedge/kubeedge                                  kubeedge/kubeedge                    kubeedge                  kubeedge
# 8       sandbox                    Provisioning          Provisioning / Automation & Configuration                              Meshery                 https://github.com/meshery/meshery                                    meshery/meshery                     meshery                   meshery
# 9       sandbox                    Provisioning          Provisioning / Automation & Configuration                               Metal³    https://github.com/metal3-io/baremetal-operator                       metal3-io/baremetal-operator                   metal3-io        baremetal-operator
# 10      sandbox                    Provisioning          Provisioning / Automation & Configuration                             OpenYurt             https://github.com/openyurtio/openyurt                                openyurtio/openyurt                  openyurtio                  openyurt
# 11      sandbox                    Provisioning          Provisioning / Automation & Configuration                            SuperEdge             https://github.com/superedge/superedge                                superedge/superedge                   superedge                 superedge
# 12      sandbox                    Provisioning          Provisioning / Automation & Configuration                           Tinkerbell                 https://github.com/tinkerbell/tink                                    tinkerbell/tink                  tinkerbell                      tink
# 13      sandbox                    Provisioning                  Provisioning / Container Registry                         Distribution       https://github.com/distribution/distribution                          distribution/distribution                distribution              distribution
# 14   incubating                    Provisioning                  Provisioning / Container Registry                            Dragonfly         https://github.com/dragonflyoss/Dragonfly2                            dragonflyoss/Dragonfly2                dragonflyoss                Dragonfly2
# 15    graduated                    Provisioning                  Provisioning / Container Registry                               Harbor                 https://github.com/goharbor/harbor                                    goharbor/harbor                    goharbor                    harbor
# 16      sandbox                    Provisioning                  Provisioning / Container Registry                                  zot                 https://github.com/project-zot/zot                                    project-zot/zot                 project-zot                       zot
# 17   incubating                    Provisioning               Provisioning / Security & Compliance                         cert-manager       https://github.com/cert-manager/cert-manager                          cert-manager/cert-manager                cert-manager              cert-manager
# 18      sandbox                    Provisioning               Provisioning / Security & Compliance              Confidential Containers  https://github.com/confidential-containers/ope...                   confidential-containers/operator     confidential-containers                  operator
# 19      sandbox                    Provisioning               Provisioning / Security & Compliance                         ContainerSSH       https://github.com/containerssh/containerssh                          containerssh/containerssh                containerssh              containerssh
# 20      sandbox                    Provisioning               Provisioning / Security & Compliance                           Curiefense           https://github.com/curiefense/curiefense                              curiefense/curiefense                  curiefense                curiefense
# 21      sandbox                    Provisioning               Provisioning / Security & Compliance                                  Dex                      https://github.com/dexidp/dex                                         dexidp/dex                      dexidp                       dex
# 22      sandbox                    Provisioning               Provisioning / Security & Compliance                     external-secrets  https://github.com/external-secrets/external-s...                  external-secrets/external-secrets            external-secrets          external-secrets
# 23   incubating                    Provisioning               Provisioning / Security & Compliance                                Falco             https://github.com/falcosecurity/falco                                falcosecurity/falco               falcosecurity                     falco
# 24      sandbox                    Provisioning               Provisioning / Security & Compliance                                 Hexa    https://github.com/hexa-org/policy-orchestrator                       hexa-org/policy-orchestrator                    hexa-org       policy-orchestrator
# 25   incubating                    Provisioning               Provisioning / Security & Compliance                              in-toto                 https://github.com/in-toto/in-toto                                    in-toto/in-toto                     in-toto                   in-toto
# 26   incubating                    Provisioning               Provisioning / Security & Compliance                             Keycloak               https://github.com/keycloak/keycloak                                  keycloak/keycloak                    keycloak                  keycloak
# 27      sandbox                    Provisioning               Provisioning / Security & Compliance                              Keylime                 https://github.com/keylime/keylime                                    keylime/keylime                     keylime                   keylime
# 28      sandbox                    Provisioning               Provisioning / Security & Compliance                            KubeArmor             https://github.com/kubearmor/kubearmor                                kubearmor/kubearmor                   kubearmor                 kubearmor
# 29      sandbox                    Provisioning               Provisioning / Security & Compliance                            Kubescape             https://github.com/kubescape/kubescape                                kubescape/kubescape                   kubescape                 kubescape
# 30      sandbox                    Provisioning               Provisioning / Security & Compliance                           Kubewarden  https://github.com/kubewarden/kubewarden-contr...                   kubewarden/kubewarden-controller                  kubewarden     kubewarden-controller
# 31   incubating                    Provisioning               Provisioning / Security & Compliance                              Kyverno                 https://github.com/kyverno/kyverno                                    kyverno/kyverno                     kyverno                   kyverno
# 32   incubating                    Provisioning               Provisioning / Security & Compliance                               Notary          https://github.com/notaryproject/notation                             notaryproject/notation               notaryproject                  notation
# 33    graduated                    Provisioning               Provisioning / Security & Compliance              Open Policy Agent (OPA)           https://github.com/open-policy-agent/opa                              open-policy-agent/opa           open-policy-agent                       opa
# 34      sandbox                    Provisioning               Provisioning / Security & Compliance               Open Policy Containers                  https://github.com/opcr-io/policy                                     opcr-io/policy                     opcr-io                    policy
# 35      sandbox                    Provisioning               Provisioning / Security & Compliance                              OpenFGA                 https://github.com/openfga/openfga                                    openfga/openfga                     openfga                   openfga
# 36      sandbox                    Provisioning               Provisioning / Security & Compliance                              Paralus                 https://github.com/paralus/paralus                                    paralus/paralus                     paralus                   paralus
# 37      sandbox                    Provisioning               Provisioning / Security & Compliance                               Parsec           https://github.com/parallaxsecond/parsec                              parallaxsecond/parsec              parallaxsecond                    parsec
# 38      sandbox                    Provisioning               Provisioning / Security & Compliance                          SlimToolkit                https://github.com/slimtoolkit/slim                                   slimtoolkit/slim                 slimtoolkit                      slim
# 39      sandbox                    Provisioning               Provisioning / Security & Compliance                                 SOPS                    https://github.com/getsops/sops                                       getsops/sops                     getsops                      sops
# 40    graduated                    Provisioning               Provisioning / Security & Compliance           The Update Framework (TUF)   https://github.com/theupdateframework/python-tuf                      theupdateframework/python-tuf          theupdateframework                python-tuf
# 41      sandbox                    Provisioning                      Provisioning / Key Management                               Athenz                   https://github.com/AthenZ/athenz                                      AthenZ/athenz                      AthenZ                    athenz
# 42    graduated                    Provisioning                      Provisioning / Key Management                               SPIFFE                   https://github.com/spiffe/spiffe                                      spiffe/spiffe                      spiffe                    spiffe
# 43    graduated                    Provisioning                      Provisioning / Key Management                                SPIRE                    https://github.com/spiffe/spire                                       spiffe/spire                      spiffe                     spire
# 44      sandbox                    Provisioning                      Provisioning / Key Management                               Teller                https://github.com/tellerops/teller                                   tellerops/teller                   tellerops                    teller
# 45      sandbox                         Runtime                     Runtime / Cloud Native Storage                               Carina                https://github.com/carina-io/carina                                   carina-io/carina                   carina-io                    carina
# 46   incubating                         Runtime                     Runtime / Cloud Native Storage                               CubeFS                   https://github.com/cubeFS/cubefs                                      cubeFS/cubefs                      cubeFS                    cubefs
# 47      sandbox                         Runtime                     Runtime / Cloud Native Storage                                Curve                 https://github.com/opencurve/curve                                    opencurve/curve                   opencurve                     curve
# 48      sandbox                         Runtime                     Runtime / Cloud Native Storage                           HwameiStor           https://github.com/hwameistor/hwameistor                              hwameistor/hwameistor                  hwameistor                hwameistor
# 49      sandbox                         Runtime                     Runtime / Cloud Native Storage                                 K8up                    https://github.com/k8up-io/k8up                                       k8up-io/k8up                     k8up-io                      k8up
# 50   incubating                         Runtime                     Runtime / Cloud Native Storage                             Longhorn               https://github.com/longhorn/longhorn                                  longhorn/longhorn                    longhorn                  longhorn
# 51      sandbox                         Runtime                     Runtime / Cloud Native Storage                              OpenEBS                 https://github.com/openebs/openebs                                    openebs/openebs                     openebs                   openebs
# 52      sandbox                         Runtime                     Runtime / Cloud Native Storage                                 ORAS               https://github.com/oras-project/oras                                  oras-project/oras                oras-project                      oras
# 53      sandbox                         Runtime                     Runtime / Cloud Native Storage                    Piraeus Datastore  https://github.com/piraeusdatastore/piraeus-op...                  piraeusdatastore/piraeus-operator            piraeusdatastore          piraeus-operator
# 54    graduated                         Runtime                     Runtime / Cloud Native Storage                                 Rook                       https://github.com/rook/rook                                          rook/rook                        rook                      rook
# 55      sandbox                         Runtime                     Runtime / Cloud Native Storage                             Vineyard                      https://github.com/v6d-io/v6d                                         v6d-io/v6d                      v6d-io                       v6d
# 56    graduated                         Runtime                        Runtime / Container Runtime                           containerd           https://github.com/containerd/containerd                              containerd/containerd                  containerd                containerd
# 57    graduated                         Runtime                        Runtime / Container Runtime                                CRI-O                     https://github.com/cri-o/cri-o                                        cri-o/cri-o                       cri-o                     cri-o
# 58      sandbox                         Runtime                        Runtime / Container Runtime                 Inclavare Containers  https://github.com/inclavare-containers/inclav...          inclavare-containers/inclavare-containers        inclavare-containers      inclavare-containers
# 59      sandbox                         Runtime                        Runtime / Container Runtime                             Krustlet               https://github.com/krustlet/krustlet                                  krustlet/krustlet                    krustlet                  krustlet
# 60      sandbox                         Runtime                        Runtime / Container Runtime                                 Lima                    https://github.com/lima-vm/lima                                       lima-vm/lima                     lima-vm                      lima
# 61      sandbox                         Runtime                        Runtime / Container Runtime                      Virtual Kubelet  https://github.com/virtual-kubelet/virtual-kub...                    virtual-kubelet/virtual-kubelet             virtual-kubelet           virtual-kubelet
# 62      sandbox                         Runtime                        Runtime / Container Runtime                     WasmEdge Runtime               https://github.com/WasmEdge/WasmEdge                                  WasmEdge/WasmEdge                    WasmEdge                  WasmEdge
# 63      sandbox                         Runtime                     Runtime / Cloud Native Network                               Antrea                https://github.com/antrea-io/antrea                                   antrea-io/antrea                   antrea-io                    antrea
# 64    graduated                         Runtime                     Runtime / Cloud Native Network                               Cilium                   https://github.com/cilium/cilium                                      cilium/cilium                      cilium                    cilium
# 65      sandbox                         Runtime                     Runtime / Cloud Native Network                            CNI-Genie             https://github.com/cni-genie/CNI-Genie                                cni-genie/CNI-Genie                   cni-genie                 CNI-Genie
# 66   incubating                         Runtime                     Runtime / Cloud Native Network    Container Network Interface (CNI)         https://github.com/containernetworking/cni                            containernetworking/cni         containernetworking                       cni
# 67      sandbox                         Runtime                     Runtime / Cloud Native Network                              FabEdge                 https://github.com/FabEdge/fabedge                                    FabEdge/fabedge                     FabEdge                   fabedge
# 68      sandbox                         Runtime                     Runtime / Cloud Native Network                             Kube-OVN                https://github.com/kubeovn/kube-ovn                                   kubeovn/kube-ovn                     kubeovn                  kube-ovn
# 69      sandbox                         Runtime                     Runtime / Cloud Native Network                             kube-vip               https://github.com/kube-vip/kube-vip                                  kube-vip/kube-vip                    kube-vip                  kube-vip
# 70      sandbox                         Runtime                     Runtime / Cloud Native Network                 Network Service Mesh          https://github.com/networkservicemesh/api                             networkservicemesh/api          networkservicemesh                       api
# 71      sandbox                         Runtime                     Runtime / Cloud Native Network                           Submariner        https://github.com/submariner-io/submariner                           submariner-io/submariner               submariner-io                submariner
# 72      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                               Armada            https://github.com/armadaproject/armada                               armadaproject/armada               armadaproject                    armada
# 73      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                              Capsule          https://github.com/projectcapsule/capsule                             projectcapsule/capsule              projectcapsule                   capsule
# 74      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                           Clusternet           https://github.com/clusternet/clusternet                              clusternet/clusternet                  clusternet                clusternet
# 75      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                         Clusterpedia    https://github.com/clusterpedia-io/clusterpedia                       clusterpedia-io/clusterpedia             clusterpedia-io              clusterpedia
# 76   incubating      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                           Crossplane           https://github.com/crossplane/crossplane                              crossplane/crossplane                  crossplane                crossplane
# 77      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                               Eraser               https://github.com/eraser-dev/eraser                                  eraser-dev/eraser                  eraser-dev                    eraser
# 78      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                                Fluid         https://github.com/fluid-cloudnative/fluid                            fluid-cloudnative/fluid           fluid-cloudnative                     fluid
# 79      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                              Karmada              https://github.com/karmada-io/karmada                                 karmada-io/karmada                  karmada-io                   karmada
# 80      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                                  kcp                     https://github.com/kcp-dev/kcp                                        kcp-dev/kcp                     kcp-dev                       kcp
# 81    graduated      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                                 KEDA                   https://github.com/kedacore/keda                                      kedacore/keda                    kedacore                      keda
# 82   incubating      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                              Knative                 https://github.com/knative/serving                                    knative/serving                     knative                   serving
# 83      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                              kube-rs                 https://github.com/kube-rs/kube-rs                                    kube-rs/kube-rs                     kube-rs                   kube-rs
# 84   incubating      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                             Kubeflow               https://github.com/kubeflow/kubeflow                                  kubeflow/kubeflow                    kubeflow                  kubeflow
# 85    graduated      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                           Kubernetes           https://github.com/kubernetes/kubernetes                              kubernetes/kubernetes                  kubernetes                kubernetes
# 86      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                                Kured                https://github.com/kubereboot/kured                                   kubereboot/kured                  kubereboot                     kured
# 87      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...              Open Cluster Management  https://github.com/open-cluster-management-io/api                     open-cluster-management-io/api  open-cluster-management-io                       api
# 88      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                         OpenFunction       https://github.com/OpenFunction/OpenFunction                          OpenFunction/OpenFunction                OpenFunction              OpenFunction
# 89      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                      Serverless Devs  https://github.com/serverless-devs/serverless-...                    serverless-devs/serverless-devs             serverless-devs           serverless-devs
# 90   incubating      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                              Volcano              https://github.com/volcano-sh/volcano                                 volcano-sh/volcano                  volcano-sh                   volcano
# 91      sandbox      Orchestration & Management  Orchestration & Management / Scheduling & Orch...                            wasmCloud             https://github.com/wasmCloud/wasmCloud                                wasmCloud/wasmCloud                   wasmCloud                 wasmCloud
# 92    graduated      Orchestration & Management  Orchestration & Management / Coordination & Se...                              CoreDNS                 https://github.com/coredns/coredns                                    coredns/coredns                     coredns                   coredns
# 93    graduated      Orchestration & Management  Orchestration & Management / Coordination & Se...                                 etcd                    https://github.com/etcd-io/etcd                                       etcd-io/etcd                     etcd-io                      etcd
# 94      sandbox      Orchestration & Management  Orchestration & Management / Coordination & Se...                                 k8gb                    https://github.com/k8gb-io/k8gb                                       k8gb-io/k8gb                     k8gb-io                      k8gb
# 95      sandbox      Orchestration & Management  Orchestration & Management / Coordination & Se...                                Xline                  https://github.com/xline-kv/Xline                                     xline-kv/Xline                    xline-kv                     Xline
# 96   incubating      Orchestration & Management  Orchestration & Management / Remote Procedure ...                                 gRPC                       https://github.com/grpc/grpc                                          grpc/grpc                        grpc                      grpc
# 97      sandbox      Orchestration & Management         Orchestration & Management / Service Proxy                                  BFE                 https://github.com/bfenetworks/bfe                                    bfenetworks/bfe                 bfenetworks                       bfe
# 98   incubating      Orchestration & Management         Orchestration & Management / Service Proxy                              Contour          https://github.com/projectcontour/contour                             projectcontour/contour              projectcontour                   contour
# 99    graduated      Orchestration & Management         Orchestration & Management / Service Proxy                                Envoy                https://github.com/envoyproxy/envoy                                   envoyproxy/envoy                  envoyproxy                     envoy
# 100     sandbox      Orchestration & Management         Orchestration & Management / Service Proxy                              MetalLB                 https://github.com/metallb/metallb                                    metallb/metallb                     metallb                   metallb
# 101     sandbox      Orchestration & Management         Orchestration & Management / Service Proxy                              OpenELB                 https://github.com/openelb/openelb                                    openelb/openelb                     openelb                   openelb
# 102  incubating      Orchestration & Management           Orchestration & Management / API Gateway                     Emissary-Ingress       https://github.com/emissary-ingress/emissary                          emissary-ingress/emissary            emissary-ingress                  emissary
# 103     sandbox      Orchestration & Management          Orchestration & Management / Service Mesh                          Aeraki Mesh              https://github.com/aeraki-mesh/aeraki                                 aeraki-mesh/aeraki                 aeraki-mesh                    aeraki
# 104   graduated      Orchestration & Management          Orchestration & Management / Service Mesh                                Istio                     https://github.com/istio/istio                                        istio/istio                       istio                     istio
# 105     sandbox      Orchestration & Management          Orchestration & Management / Service Mesh                                 Kuma                     https://github.com/kumahq/kuma                                        kumahq/kuma                      kumahq                      kuma
# 106   graduated      Orchestration & Management          Orchestration & Management / Service Mesh                              Linkerd                https://github.com/linkerd/linkerd2                                   linkerd/linkerd2                     linkerd                  linkerd2
# 107     sandbox      Orchestration & Management          Orchestration & Management / Service Mesh                            Merbridge             https://github.com/merbridge/merbridge                                merbridge/merbridge                   merbridge                 merbridge
# 108     sandbox      Orchestration & Management          Orchestration & Management / Service Mesh             Service Mesh Performance  https://github.com/service-mesh-performance/se...  service-mesh-performance/service-mesh-performance    service-mesh-performance  service-mesh-performance
# 109     sandbox  App Definition and Development          App Definition and Development / Database                           SchemaHero           https://github.com/schemahero/schemahero                              schemahero/schemahero                  schemahero                schemahero
# 110   graduated  App Definition and Development          App Definition and Development / Database                                 TiKV                       https://github.com/tikv/tikv                                          tikv/tikv                        tikv                      tikv
# 111   graduated  App Definition and Development          App Definition and Development / Database                               Vitess                 https://github.com/vitessio/vitess                                    vitessio/vitess                    vitessio                    vitess
# 112  incubating  App Definition and Development  App Definition and Development / Streaming & M...                          CloudEvents                https://github.com/cloudevents/spec                                   cloudevents/spec                 cloudevents                      spec
# 113  incubating  App Definition and Development  App Definition and Development / Streaming & M...                                 NATS             https://github.com/nats-io/nats-server                                nats-io/nats-server                     nats-io               nats-server
# 114     sandbox  App Definition and Development  App Definition and Development / Streaming & M...                              Pravega                 https://github.com/pravega/pravega                                    pravega/pravega                     pravega                   pravega
# 115     sandbox  App Definition and Development  App Definition and Development / Streaming & M...                              Strimzi  https://github.com/strimzi/strimzi-kafka-operator                     strimzi/strimzi-kafka-operator                     strimzi    strimzi-kafka-operator
# 116     sandbox  App Definition and Development  App Definition and Development / Streaming & M...                               Tremor        https://github.com/tremor-rs/tremor-runtime                           tremor-rs/tremor-runtime                   tremor-rs            tremor-runtime
# 117     sandbox  App Definition and Development  App Definition and Development / Application D...                         Artifact Hub                 https://github.com/artifacthub/hub                                    artifacthub/hub                 artifacthub                       hub
# 118  incubating  App Definition and Development  App Definition and Development / Application D...                            Backstage             https://github.com/backstage/backstage                                backstage/backstage                   backstage                 backstage
# 119  incubating  App Definition and Development  App Definition and Development / Application D...                           Buildpacks                 https://github.com/buildpacks/pack                                    buildpacks/pack                  buildpacks                      pack
# 120     sandbox  App Definition and Development  App Definition and Development / Application D...                               Carvel                  https://github.com/carvel-dev/ytt                                     carvel-dev/ytt                  carvel-dev                       ytt
# 121  incubating  App Definition and Development  App Definition and Development / Application D...                                 Dapr                       https://github.com/dapr/dapr                                          dapr/dapr                        dapr                      dapr
# 122     sandbox  App Definition and Development  App Definition and Development / Application D...                              Devfile                     https://github.com/devfile/api                                        devfile/api                     devfile                       api
# 123     sandbox  App Definition and Development  App Definition and Development / Application D...                             DevSpace   https://github.com/devspace-cloud/devspace-cloud                      devspace-cloud/devspace-cloud              devspace-cloud            devspace-cloud
# 124   graduated  App Definition and Development  App Definition and Development / Application D...                                 Helm                       https://github.com/helm/helm                                          helm/helm                        helm                      helm
# 125     sandbox  App Definition and Development  App Definition and Development / Application D...                                   ko                     https://github.com/ko-build/ko                                        ko-build/ko                    ko-build                        ko
# 126     sandbox  App Definition and Development  App Definition and Development / Application D...                             Konveyor       https://github.com/konveyor/tackle2-operator                          konveyor/tackle2-operator                    konveyor          tackle2-operator
# 127     sandbox  App Definition and Development  App Definition and Development / Application D...                               Krator                https://github.com/krator-rs/krator                                   krator-rs/krator                   krator-rs                    krator
# 128  incubating  App Definition and Development  App Definition and Development / Application D...                             KubeVela               https://github.com/kubevela/kubevela                                  kubevela/kubevela                    kubevela                  kubevela
# 129  incubating  App Definition and Development  App Definition and Development / Application D...                             KubeVirt               https://github.com/kubevirt/kubevirt                                  kubevirt/kubevirt                    kubevirt                  kubevirt
# 130     sandbox  App Definition and Development  App Definition and Development / Application D...                                 KUDO                https://github.com/kudobuilder/kudo                                   kudobuilder/kudo                 kudobuilder                      kudo
# 131     sandbox  App Definition and Development  App Definition and Development / Application D...                             Microcks               https://github.com/microcks/microcks                                  microcks/microcks                    microcks                  microcks
# 132     sandbox  App Definition and Development  App Definition and Development / Application D...                            Nocalhost             https://github.com/nocalhost/nocalhost                                nocalhost/nocalhost                   nocalhost                 nocalhost
# 133  incubating  App Definition and Development  App Definition and Development / Application D...                   Operator Framework  https://github.com/operator-framework/operator...                    operator-framework/operator-sdk          operator-framework              operator-sdk
# 134     sandbox  App Definition and Development  App Definition and Development / Application D...                               Porter                https://github.com/getporter/porter                                   getporter/porter                   getporter                    porter
# 135     sandbox  App Definition and Development  App Definition and Development / Application D...                               sealer                 https://github.com/sealerio/sealer                                    sealerio/sealer                    sealerio                    sealer
# 136     sandbox  App Definition and Development  App Definition and Development / Application D...                  Serverless Workflow  https://github.com/serverlessworkflow/specific...                   serverlessworkflow/specification          serverlessworkflow             specification
# 137     sandbox  App Definition and Development  App Definition and Development / Application D...                         Telepresence     https://github.com/telepresenceio/telepresence                        telepresenceio/telepresence              telepresenceio              telepresence
# 138     sandbox  App Definition and Development  App Definition and Development / Application D...  Visual Studio Code Kubernetes Tools  https://github.com/vscode-kubernetes-tools/vsc...    vscode-kubernetes-tools/vscode-kubernetes-tools     vscode-kubernetes-tools   vscode-kubernetes-tools
# 139   graduated  App Definition and Development  App Definition and Development / Continuous In...                                 Argo                https://github.com/argoproj/argo-cd                                   argoproj/argo-cd                    argoproj                   argo-cd
# 140   graduated  App Definition and Development  App Definition and Development / Continuous In...                                 Flux                    https://github.com/fluxcd/flux2                                       fluxcd/flux2                      fluxcd                     flux2
# 141  incubating  App Definition and Development  App Definition and Development / Continuous In...                                Keptn                     https://github.com/keptn/keptn                                        keptn/keptn                       keptn                     keptn
# 142     sandbox  App Definition and Development  App Definition and Development / Continuous In...                          OpenFeature               https://github.com/open-feature/spec                                  open-feature/spec                open-feature                      spec
# 143     sandbox  App Definition and Development  App Definition and Development / Continuous In...                           OpenGitOps             https://github.com/open-gitops/project                                open-gitops/project                 open-gitops                   project
# 144  incubating  App Definition and Development  App Definition and Development / Continuous In...                           OpenKruise               https://github.com/openkruise/kruise                                  openkruise/kruise                  openkruise                    kruise
# 145     sandbox  App Definition and Development  App Definition and Development / Continuous In...                               PipeCD                  https://github.com/pipe-cd/pipecd                                     pipe-cd/pipecd                     pipe-cd                    pipecd
# 146     sandbox  App Definition and Development  App Definition and Development / Continuous In...                                 werf                       https://github.com/werf/werf                                          werf/werf                        werf                      werf
# 147     sandbox                        Platform     Platform / Certified Kubernetes - Distribution                                  k3s                      https://github.com/k3s-io/k3s                                         k3s-io/k3s                      k3s-io                       k3s
# 148     sandbox                        Platform        Platform / Certified Kubernetes - Installer                          KubeClipper         https://github.com/kubeclipper/kubeclipper                            kubeclipper/kubeclipper                 kubeclipper               kubeclipper
# 150  incubating                      Serverless                             Serverless / Framework                    Dapr (Serverless)                       https://github.com/dapr/dapr                                          dapr/dapr                        dapr                      dapr
# 151   graduated                      Serverless                  Serverless / Installable Platform                    KEDA (Serverless)                   https://github.com/kedacore/keda                                      kedacore/keda                    kedacore                      keda
# 152  incubating                      Serverless                  Serverless / Installable Platform                 Knative (Serverless)                 https://github.com/knative/serving                                    knative/serving                     knative                   serving
# 153     sandbox                      Serverless                  Serverless / Installable Platform            OpenFunction (Serverless)       https://github.com/OpenFunction/OpenFunction                          OpenFunction/OpenFunction                OpenFunction              OpenFunction
# 155  incubating      Observability and Analysis            Observability and Analysis / Monitoring                               Cortex            https://github.com/cortexproject/cortex                               cortexproject/cortex               cortexproject                    cortex
# 156     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                                Fonio                   https://github.com/foniod/foniod                                      foniod/foniod                      foniod                    foniod
# 157     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                             Headlamp           https://github.com/headlamp-k8s/headlamp                              headlamp-k8s/headlamp                headlamp-k8s                  headlamp
# 158     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                     Inspektor Gadget  https://github.com/inspektor-gadget/inspektor-...                  inspektor-gadget/inspektor-gadget            inspektor-gadget          inspektor-gadget
# 159     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                               Kepler  https://github.com/sustainable-computing-io/ke...                    sustainable-computing-io/kepler    sustainable-computing-io                    kepler
# 160     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                         Kuberhealthy       https://github.com/kuberhealthy/kuberhealthy                          kuberhealthy/kuberhealthy                kuberhealthy              kuberhealthy
# 161  incubating      Observability and Analysis            Observability and Analysis / Monitoring                          OpenMetrics   https://github.com/OpenObservability/OpenMetrics                      OpenObservability/OpenMetrics           OpenObservability               OpenMetrics
# 162     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                                Pixie                  https://github.com/pixie-io/pixie                                     pixie-io/pixie                    pixie-io                     pixie
# 163   graduated      Observability and Analysis            Observability and Analysis / Monitoring                           Prometheus           https://github.com/prometheus/prometheus                              prometheus/prometheus                  prometheus                prometheus
# 164     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                              Skooner             https://github.com/skooner-k8s/skooner                                skooner-k8s/skooner                 skooner-k8s                   skooner
# 165  incubating      Observability and Analysis            Observability and Analysis / Monitoring                               Thanos                https://github.com/thanos-io/thanos                                   thanos-io/thanos                   thanos-io                    thanos
# 166     sandbox      Observability and Analysis            Observability and Analysis / Monitoring                            Trickster        https://github.com/trickstercache/trickster                           trickstercache/trickster              trickstercache                 trickster
# 167   graduated      Observability and Analysis               Observability and Analysis / Logging                              Fluentd                  https://github.com/fluent/fluentd                                     fluent/fluentd                      fluent                   fluentd
# 168   graduated      Observability and Analysis               Observability and Analysis / Tracing                               Jaeger            https://github.com/jaegertracing/jaeger                               jaegertracing/jaeger               jaegertracing                    jaeger
# 169  incubating      Observability and Analysis               Observability and Analysis / Tracing                        OpenTelemetry  https://github.com/open-telemetry/opentelemetr...                  open-telemetry/opentelemetry-java              open-telemetry        opentelemetry-java
# 170  incubating      Observability and Analysis     Observability and Analysis / Chaos Engineering                           Chaos Mesh           https://github.com/chaos-mesh/chaos-mesh                              chaos-mesh/chaos-mesh                  chaos-mesh                chaos-mesh
# 171     sandbox      Observability and Analysis     Observability and Analysis / Chaos Engineering                           Chaosblade        https://github.com/chaosblade-io/chaosblade                           chaosblade-io/chaosblade               chaosblade-io                chaosblade
# 172  incubating      Observability and Analysis     Observability and Analysis / Chaos Engineering                               Litmus              https://github.com/litmuschaos/litmus                                 litmuschaos/litmus                 litmuschaos                    litmus
# 173     sandbox      Observability and Analysis  Observability and Analysis / Continuous Optimi...                             OpenCost               https://github.com/opencost/opencost                                  opencost/opencost                    opencost                  opencost
# 174     sandbox                            Wasm                                    Wasm / Runtimes                      Krustlet (Wasm)               https://github.com/krustlet/krustlet                                  krustlet/krustlet                    krustlet                  krustlet
# 175     sandbox                            Wasm                                    Wasm / Runtimes                      WasmEdge (Wasm)               https://github.com/WasmEdge/WasmEdge                                  WasmEdge/WasmEdge                    WasmEdge                  WasmEdge
# 176     sandbox                            Wasm                          Wasm / Embedded Functions                    Kubewarden (Wasm)  https://github.com/kubewarden/kubewarden-contr...                   kubewarden/kubewarden-controller                  kubewarden     kubewarden-controller
# 177     sandbox                            Wasm                          Wasm / Embedded Functions                  OpenFunction (Wasm)       https://github.com/OpenFunction/OpenFunction                          OpenFunction/OpenFunction                OpenFunction              OpenFunction

# %%
# Visual Python: Data Analysis > Subset
otag_repos_by_relation = df_tiny.query("`category` == 'Observability and Analysis'")[['relation','repo', 'name']].copy()
otag_repos_by_relation.groupby('relation')['repo'].agg(lambda x: list(x)).to_dict()

safe_set_index(otag_repos_by_relation, idx_wanted=['relation', 'name'])
otag_repos_by_relation.sort_index()
# Out:
#                                                           repo
# relation   name
# graduated  Fluentd                              fluent/fluentd
#            Jaeger                         jaegertracing/jaeger
#            Prometheus                    prometheus/prometheus
# incubating Chaos Mesh                    chaos-mesh/chaos-mesh
#            Cortex                         cortexproject/cortex
#            Litmus                           litmuschaos/litmus
#            OpenMetrics           OpenObservability/OpenMetrics
#            OpenTelemetry     open-telemetry/opentelemetry-java
#            Thanos                             thanos-io/thanos
# sandbox    Chaosblade                 chaosblade-io/chaosblade
#            Fonio                                 foniod/foniod
#            Headlamp                      headlamp-k8s/headlamp
#            Inspektor Gadget  inspektor-gadget/inspektor-gadget
#            Kepler              sustainable-computing-io/kepler
#            Kuberhealthy              kuberhealthy/kuberhealthy
#            OpenCost                          opencost/opencost
#            Pixie                                pixie-io/pixie
#            Skooner                         skooner-k8s/skooner
#            Trickster                  trickstercache/trickster

# %%
graduated  = otag_repos_by_relation.loc['graduated', :]['repo'].tolist()
incubating = otag_repos_by_relation.loc['incubating', :]['repo'].tolist()
sandbox    = otag_repos_by_relation.loc['sandbox', :]['repo'].tolist()

display(graduated, incubating, sandbox)
# Out:
# ['fluent/fluentd', 'jaegertracing/jaeger', 'prometheus/prometheus']
# ['chaos-mesh/chaos-mesh',
#  'cortexproject/cortex',
#  'litmuschaos/litmus',
#  'OpenObservability/OpenMetrics',
#  'open-telemetry/opentelemetry-java',
#  'thanos-io/thanos']
# ['chaosblade-io/chaosblade',
#  'foniod/foniod',
#  'headlamp-k8s/headlamp',
#  'inspektor-gadget/inspektor-gadget',
#  'sustainable-computing-io/kepler',
#  'kuberhealthy/kuberhealthy',
#  'opencost/opencost',
#  'pixie-io/pixie',
#  'skooner-k8s/skooner',
#  'trickstercache/trickster']

# %% [markdown]
# ## Fetch project release data from GitHub API

# %%
import time
import os
import json
import pandas as pd
from typing import List
from datetime import datetime, timezone
from github import Github, GithubException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

def fetch_repo_data(token: str, 
                    repo_list: List[str], 
                    since: datetime=None, 
                    json_file: str=None, 
                    csv_file: str=None, 
                    state_file: str=None) -> pd.DataFrame:

    # Initialize DataFrame
    # df = pd.DataFrame(columns=[
    #     'repo_name', 'release_name', 'release_date', 
    #     'language', 'release_notes'
    # ])

    df = pd.DataFrame(columns=['repo_name', 'release_name', 'release_date', 'language'])

    # Initialize GitHub client
    g = Github(token)

    # Initialize loop state
    if state_file:
        try:
            with open(state_file, 'r') as f:
                state = json.load(f)
        except FileNotFoundError:
            state = {'i': 0, 'repos_done': []}
    else:
        state = {'i': 0, 'repos_done': []}

    # Loop over repositories
    while state['i'] < len(repo_list):
        repo_str = repo_list[state['i']]

        if repo_str in state['repos_done']:
            print(f"Skipping: {repo_str}")
            state['i'] += 1
            continue

        while True:
            try:
                repo = g.get_repo(repo_str)
                break
            except GithubException as e:
                if e.status == 404:
                    print(f"Repository {repo_str} not found")
                    break
                elif e.status == 429:
                    print(f"Rate limit exceeded, waiting for {e.headers['Retry-After']} seconds...")
                    time.sleep(int(e.headers['Retry-After']))
                else:
                    print(f"Error getting repository {repo_str}: {e}")
                    break

        if not repo:
            state['i'] += 1
            continue

        # Get all releases
        releases = repo.get_releases()
        language = repo.language

        for release in releases:
            if since is None or release.created_at >= since:
                df = pd.concat([df, pd.DataFrame({
                    'repo_name': [repo_str],
                    'release_name': [release.title],
                    'release_date': [str(release.published_at)],
                    'language': [language],
                    #'release_notes': [release.body]
                })])
                print(f"Added {release.published_at}, {repo_str}::{release.title}  ")

        # Save state
        if state_file:
            state['repos_done'].append(repo_str)
            with open(state_file, 'w') as f:
                json.dump(state, f, indent=4)

        state['i'] += 1

    #print (releases)
    
    # Save as CSV
    if csv_file:
        df.to_csv(csv_file, index=False)

    # Save as JSON
    if json_file:
        df.to_json(json_file, orient='records', lines=True)
    return df

# %%
otag_repos_by_relation
# Out:
#                                                           repo
# relation   name
# graduated  Fluentd                              fluent/fluentd
#            Jaeger                         jaegertracing/jaeger
#            Prometheus                    prometheus/prometheus
# incubating Chaos Mesh                    chaos-mesh/chaos-mesh
#            Cortex                         cortexproject/cortex
#            Litmus                           litmuschaos/litmus
#            OpenMetrics           OpenObservability/OpenMetrics
#            OpenTelemetry     open-telemetry/opentelemetry-java
#            Thanos                             thanos-io/thanos
# sandbox    Chaosblade                 chaosblade-io/chaosblade
#            Fonio                                 foniod/foniod
#            Headlamp                      headlamp-k8s/headlamp
#            Inspektor Gadget  inspektor-gadget/inspektor-gadget
#            Kepler              sustainable-computing-io/kepler
#            Kuberhealthy              kuberhealthy/kuberhealthy
#            OpenCost                          opencost/opencost
#            Pixie                                pixie-io/pixie
#            Skooner                         skooner-k8s/skooner
#            Trickster                  trickstercache/trickster

# %%
# !mkdir -p out

# %%
def fetch_one(token, since_date, level, repos):

    json_file=f'out/cncf-{level}-github-releases.json' 
    csv_file=f'out/cncf-{level}-github-releases.csv'
    state_file=f'out/.nukeme_state_file_{level}'
    
    print(f"Fetching {len(repos)} repositories for {level} projects")
    
    releases = fetch_repo_data( token, 
                                repos, 
                                since=since_date,
                                json_file=json_file,
                                csv_file=csv_file)

# %%
token = os.environ['GITHUB_TOKEN']
since_date = datetime(2022, 11, 7, tzinfo=timezone.utc)

fetch_one(token, since_date, 'otag-graduated', graduated)
# Out:
# Fetching 3 repositories for otag-graduated projects
# Added 2023-07-14 08:27:02+00:00, fluent/fluentd::Fluentd v1.16.2
# Added 2023-04-17 07:51:15+00:00, fluent/fluentd::Fluentd v1.16.1
# Added 2023-03-29 04:04:47+00:00, fluent/fluentd::Fluentd v1.16.0
# Added 2023-11-02 23:58:27+00:00, jaegertracing/jaeger::Release v1.51.0
# Added 2023-10-06 16:26:16+00:00, jaegertracing/jaeger::Release v1.50.0
# Added 2023-09-07 14:07:29+00:00, jaegertracing/jaeger::Release v1.49.0
# Added 2023-08-15 11:39:36+00:00, jaegertracing/jaeger::Release 1.48.0
# Added 2023-07-07 01:22:45+00:00, jaegertracing/jaeger::Release 1.47.0
# Added 2023-06-05 02:47:29+00:00, jaegertracing/jaeger::Release v1.46.0
# Added 2023-05-05 21:02:00+00:00, jaegertracing/jaeger::Release v1.45.0
# Added 2023-04-10 19:33:37+00:00, jaegertracing/jaeger::Release v1.44.0
# Added 2023-03-15 18:09:45+00:00, jaegertracing/jaeger::Release 1.43.0
# Added 2023-02-05 21:06:06+00:00, jaegertracing/jaeger::Release v1.42.0
# Added 2023-01-04 06:28:00+00:00, jaegertracing/jaeger::Release v1.41.0
# Added 2022-12-09 12:57:15+00:00, jaegertracing/jaeger::Release v1.40.0
# Added 2023-11-03 03:01:23+00:00, prometheus/prometheus::2.48.0-rc.2 / 2023-11-02
# Added 2023-10-29 16:08:07+00:00, prometheus/prometheus::2.48.0-rc.1 / 2023-10-29
# Added 2023-10-17 17:40:38+00:00, prometheus/prometheus::2.48.0-rc.0 / 2023-10-17
# Added 2023-10-15 14:20:54+00:00, prometheus/prometheus::2.47.2 / 2023-10-11
# Added 2023-10-04 11:24:46+00:00, prometheus/prometheus::2.47.1 / 2023-10-04
# Added 2023-09-30 12:47:57+00:00, prometheus/prometheus::2.45.1 / 2023-09-29
# Added 2023-09-06 11:50:31+00:00, prometheus/prometheus::2.47.0 / 2023-09-06
# Added 2023-08-31 11:54:28+00:00, prometheus/prometheus::2.47.0-rc.0 / 2023-08-25
# Added 2023-07-29 08:01:53+00:00, prometheus/prometheus::2.37.9 / 2023-07-28
# Added 2023-07-25 13:18:06+00:00, prometheus/prometheus::2.46.0 / 2023-07-25
# Added 2023-07-21 11:22:20+00:00, prometheus/prometheus::2.46.0-rc.0 / 2023-07-20
# Added 2023-06-23 16:07:55+00:00, prometheus/prometheus::2.45.0 / 2023-06-23
# Added 2023-06-20 19:52:09+00:00, prometheus/prometheus::2.45.0-rc.1 / 2023-06-20
# Added 2023-06-07 12:49:03+00:00, prometheus/prometheus::2.45.0-rc.0 / 2023-06-05
# Added 2023-05-14 08:04:08+00:00, prometheus/prometheus::2.44.0 / 2023-05-13
# Added 2023-05-08 20:05:01+00:00, prometheus/prometheus::2.44.0-rc.2 / 2023-05-07
# Added 2023-05-05 09:53:10+00:00, prometheus/prometheus::2.37.8 / 2023-05-04
# Added 2023-05-05 06:00:50+00:00, prometheus/prometheus::2.43.1+stringlabels / 2023-05-04
# Added 2023-05-05 06:00:35+00:00, prometheus/prometheus::2.43.1 / 2023-05-03
# Added 2023-05-03 16:43:38+00:00, prometheus/prometheus::2.44.0-rc.1 / 2023-05-03
# Added 2023-04-27 10:42:35+00:00, prometheus/prometheus::2.37.7 / 2023-04-27
# Added 2023-04-26 16:53:11+00:00, prometheus/prometheus::2.44.0-rc.0 / 2023-04-22
# Added 2023-03-21 13:30:32+00:00, prometheus/prometheus::2.43.0+stringlabels / 2023-03-21
# Added 2023-03-21 15:53:49+00:00, prometheus/prometheus::2.43.0 / 2023-03-21
# Added 2023-03-16 23:01:21+00:00, prometheus/prometheus::2.43.0-rc.1+stringlabels / 2023-03-16
# Added 2023-03-16 22:05:40+00:00, prometheus/prometheus::2.43.0-rc.1 / 2023-03-16
# Added 2023-03-09 16:52:20+00:00, prometheus/prometheus::2.43.0-rc.0 / 2023-03-09
# Added 2023-02-20 13:40:23+00:00, prometheus/prometheus::2.37.6 / 2023-02-20
# Added 2023-02-01 08:56:18+00:00, prometheus/prometheus::2.42.0 / 2023-01-31
# Added 2023-01-27 14:14:48+00:00, prometheus/prometheus::2.42.0-rc.0 / 2023-01-26
# Added 2022-12-20 15:58:53+00:00, prometheus/prometheus::2.41.0 / 2022-12-20
# Added 2022-12-15 21:14:24+00:00, prometheus/prometheus::2.41.0-rc.0 / 2022-12-14
# Added 2022-12-14 13:22:12+00:00, prometheus/prometheus::2.40.7 / 2022-12-14
# Added 2022-12-09 14:56:41+00:00, prometheus/prometheus::2.40.6 / 2022-12-09
# Added 2022-12-09 13:18:18+00:00, prometheus/prometheus::2.37.5 / 2022-12-09
# Added 2022-12-01 14:32:44+00:00, prometheus/prometheus::2.40.5 / 2022-12-01
# Added 2022-11-29 12:01:43+00:00, prometheus/prometheus::2.40.4 / 2022-11-29
# Added 2022-11-29 12:02:03+00:00, prometheus/prometheus::2.37.4 / 2022-11-29
# Added 2022-11-24 11:42:31+00:00, prometheus/prometheus::2.40.3 / 2022-11-23
# Added 2022-11-23 12:04:09+00:00, prometheus/prometheus::2.37.3 / 2022-11-23
# Added 2022-11-17 14:26:38+00:00, prometheus/prometheus::2.40.2 / 2022-11-16
# Added 2022-11-09 15:24:32+00:00, prometheus/prometheus::2.40.1 / 2022-11-09
# Added 2022-11-09 14:16:49+00:00, prometheus/prometheus::2.39.2 / 2022-11-09
# Added 2022-11-08 09:12:19+00:00, prometheus/prometheus::2.40.0 / 2022-11-08

# %%
fetch_one(token, since_date, 'otag-incubating', incubating)
# Out:
# Fetching 6 repositories for otag-incubating projects
# Added 2023-08-23 06:40:12+00:00, chaos-mesh/chaos-mesh::v2.6.2
# Added 2023-06-28 07:54:06+00:00, chaos-mesh/chaos-mesh::v2.6.1
# Added 2023-05-31 03:52:21+00:00, chaos-mesh/chaos-mesh::v2.6.0
# Added 2023-04-13 08:48:24+00:00, chaos-mesh/chaos-mesh::v2.5.2
# Added 2023-01-14 02:32:58+00:00, chaos-mesh/chaos-mesh::v2.5.1
# Added 2022-11-22 11:35:17+00:00, chaos-mesh/chaos-mesh::v2.5.0
# Added 2022-11-21 11:57:01+00:00, chaos-mesh/chaos-mesh::v2.5.0-beta.1
# Added 2022-11-21 11:36:52+00:00, chaos-mesh/chaos-mesh::v2.5.0-beta.0
# Added 2022-11-20 08:20:18+00:00, chaos-mesh/chaos-mesh::v2.4.3
# Added 2022-11-11 11:42:10+00:00, chaos-mesh/chaos-mesh::v2.5.0-alpha.1
# Added 2022-11-10 08:51:07+00:00, chaos-mesh/chaos-mesh::v2.5.0-alpha.0
# Added 2022-11-07 08:19:38+00:00, chaos-mesh/chaos-mesh::v2.4.2
# Added 2022-11-07 08:13:08+00:00, chaos-mesh/chaos-mesh::v2.3.3
# Added 2023-06-23 04:38:47+00:00, cortexproject/cortex::Cortex 1.15.3
# Added 2023-05-10 20:22:29+00:00, cortexproject/cortex::Cortex 1.15.2
# Added 2023-04-28 04:30:48+00:00, cortexproject/cortex::Cortex 1.15.1
# Added 2023-04-20 02:50:34+00:00, cortexproject/cortex::Cortex 1.15.0
# Added 2023-04-12 16:15:36+00:00, cortexproject/cortex::Cortex 1.15.0-rc.2
# Added 2023-04-01 19:09:23+00:00, cortexproject/cortex::Cortex 1.15.0-rc.1
# Added 2023-03-28 01:02:08+00:00, cortexproject/cortex::Cortex 1.15.0-rc.0
# Added 2022-12-18 19:35:27+00:00, cortexproject/cortex::Cortex 1.14.1
# Added 2022-12-18 19:17:25+00:00, cortexproject/cortex::Cortex 1.13.2
# Added 2022-12-02 23:51:47+00:00, cortexproject/cortex::Cortex 1.14.0
# Added 2022-11-19 02:57:59+00:00, cortexproject/cortex::Cortex 1.14.0-rc.1
# Added 2022-11-16 01:16:34+00:00, cortexproject/cortex::Cortex 1.14.0-rc.0
# Added 2023-10-04 14:09:48+00:00, litmuschaos/litmus::3.0.0
# Added 2023-09-15 13:11:19+00:00, litmuschaos/litmus::3.0.0-beta12
# Added 2023-08-16 11:24:44+00:00, litmuschaos/litmus::3.0.0-beta11
# Added 2023-07-20 05:35:34+00:00, litmuschaos/litmus::3.0.0-beta10
# Added 2023-07-06 12:12:44+00:00, litmuschaos/litmus::3.0.0-beta9
# Added 2023-06-20 06:55:52+00:00, litmuschaos/litmus::3.0.0-beta8
# Added 2023-05-17 10:31:36+00:00, litmuschaos/litmus::3.0.0-beta7
# Added 2023-04-18 14:39:44+00:00, litmuschaos/litmus::3.0.0-beta6
# Added 2023-03-15 08:24:34+00:00, litmuschaos/litmus::3.0.0-beta5
# Added 2023-02-15 13:54:10+00:00, litmuschaos/litmus::3.0.0-beta4
# Added 2023-01-13 12:25:15+00:00, litmuschaos/litmus::3.0.0-beta3
# Added 2022-12-15 16:23:34+00:00, litmuschaos/litmus::3.0.0-beta2
# Added 2022-11-16 15:25:31+00:00, litmuschaos/litmus::3.0-beta1
# Added 2023-10-06 20:57:59+00:00, open-telemetry/opentelemetry-java::Version 1.31.0
# Added 2023-09-11 16:09:45+00:00, open-telemetry/opentelemetry-java::Version 1.30.1
# Added 2023-09-08 16:40:15+00:00, open-telemetry/opentelemetry-java::Version 1.30.0
# Added 2023-08-11 16:23:10+00:00, open-telemetry/opentelemetry-java::Version 1.29.0
# Added 2023-07-07 12:31:36+00:00, open-telemetry/opentelemetry-java::Version 1.28.0
# Added 2023-06-09 17:01:01+00:00, open-telemetry/opentelemetry-java::Version 1.27.0
# Added 2023-05-05 20:02:01+00:00, open-telemetry/opentelemetry-java::Version 1.26.0
# Added 2023-04-07 14:47:42+00:00, open-telemetry/opentelemetry-java::Version 1.25.0
# Added 2023-03-10 17:26:49+00:00, open-telemetry/opentelemetry-java::Version 1.24.0
# Added 2023-02-15 20:43:51+00:00, open-telemetry/opentelemetry-java::Version 1.23.1
# Added 2023-02-10 20:35:49+00:00, open-telemetry/opentelemetry-java::Version 1.23.0
# Added 2023-01-06 15:16:08+00:00, open-telemetry/opentelemetry-java::Version 1.22.0
# Added 2022-12-09 20:02:52+00:00, open-telemetry/opentelemetry-java::Version 1.21.0
# Added 2022-11-15 20:25:53+00:00, open-telemetry/opentelemetry-java::Version 1.20.1
# Added 2022-11-11 19:23:03+00:00, open-telemetry/opentelemetry-java::Version 1.20.0
# Added 2023-10-19 04:31:03+00:00, thanos-io/thanos::v0.32.5
# Added 2023-10-02 08:02:03+00:00, thanos-io/thanos::v0.32.4
# Added 2023-09-20 07:45:37+00:00, thanos-io/thanos::v0.32.3
# Added 2023-08-31 14:13:13+00:00, thanos-io/thanos::v0.32.2
# Added 2023-08-28 11:45:21+00:00, thanos-io/thanos::v0.32.1
# Added 2023-08-23 13:55:57+00:00, thanos-io/thanos::v0.32.0
# Added 2023-08-21 09:08:12+00:00, thanos-io/thanos::v0.32.0-rc.1
# Added 2023-08-16 11:39:56+00:00, thanos-io/thanos::v0.32.0-rc.0
# Added 2023-03-23 10:32:53+00:00, thanos-io/thanos::v0.31.0
# Added 2023-03-13 11:50:07+00:00, thanos-io/thanos::v0.31.0-rc.1
# Added 2023-02-24 15:26:55+00:00, thanos-io/thanos::v0.31.0-rc.0
# Added 2023-01-31 20:28:40+00:00, thanos-io/thanos::v0.30.2
# Added 2023-01-04 19:00:39+00:00, thanos-io/thanos::v0.30.1
# Added 2023-01-03 14:42:53+00:00, thanos-io/thanos::v0.30.0
# Added 2022-12-21 17:22:13+00:00, thanos-io/thanos::v0.30.0-rc.0

# %%
fetch_one(token, since_date, 'otag-sandbox', sandbox)
# Out:
# Fetching 10 repositories for otag-sandbox projects
# Added 2023-09-15 03:25:14+00:00, chaosblade-io/chaosblade::v1.7.3
# Added 2023-05-18 14:12:20+00:00, chaosblade-io/chaosblade::v1.7.2
# Added 2022-12-15 11:30:23+00:00, chaosblade-io/chaosblade::v1.7.1
# Added 2023-11-07 23:18:14+00:00, headlamp-k8s/headlamp::0.21.0
# Added 2023-10-09 10:52:31+00:00, headlamp-k8s/headlamp::headlamp-helm-0.16.0
# Added 2023-10-05 20:30:37+00:00, headlamp-k8s/headlamp::0.20.1
# Added 2023-09-28 20:52:50+00:00, headlamp-k8s/headlamp::0.20.0
# Added 2023-08-25 16:44:48+00:00, headlamp-k8s/headlamp::headlamp-helm-0.15.0
# Added 2023-08-24 16:48:37+00:00, headlamp-k8s/headlamp::0.19.1
# Added 2023-08-03 14:00:16+00:00, headlamp-k8s/headlamp::0.19.0
# Added 2023-08-03 19:49:14+00:00, headlamp-k8s/headlamp::headlamp-helm-0.14.0
# Added 2023-07-06 15:58:44+00:00, headlamp-k8s/headlamp::headlamp-helm-0.13.0
# Added 2023-06-15 21:17:48+00:00, headlamp-k8s/headlamp::0.18.0
# Added 2023-05-29 10:42:08+00:00, headlamp-k8s/headlamp::headlamp-helm-0.12.0
# Added 2023-05-18 16:26:11+00:00, headlamp-k8s/headlamp::0.17.1
# Added 2023-04-27 22:23:18+00:00, headlamp-k8s/headlamp::0.17.0
# Added 2023-03-16 15:32:19+00:00, headlamp-k8s/headlamp::0.16.0
# Added 2023-02-17 04:27:36+00:00, headlamp-k8s/headlamp::headlamp-helm-0.11.0
# Added 2023-02-16 19:43:46+00:00, headlamp-k8s/headlamp::0.15.1
# Added 2023-02-15 10:56:47+00:00, headlamp-k8s/headlamp::headlamp-helm-0.10.0
# Added 2023-02-07 04:51:24+00:00, headlamp-k8s/headlamp::headlamp-plugin-0.5.5
# Added 2023-02-02 16:38:10+00:00, headlamp-k8s/headlamp::0.15.0
# Added 2022-12-27 11:37:45+00:00, headlamp-k8s/headlamp::headlamp-helm-0.9.0
# Added 2022-12-14 22:37:44+00:00, headlamp-k8s/headlamp::0.14.1
# Added 2022-11-24 19:26:11+00:00, headlamp-k8s/headlamp::0.14.0
# Added 2022-11-25 00:27:09+00:00, headlamp-k8s/headlamp::headlamp-plugin-0.5.4
# Added 2023-11-02 16:06:03+00:00, inspektor-gadget/inspektor-gadget::Release v0.22.0
# Added 2023-10-02 07:36:40+00:00, inspektor-gadget/inspektor-gadget::Release v0.21.0
# Added 2023-09-04 10:00:34+00:00, inspektor-gadget/inspektor-gadget::Release v0.20.0
# Added 2023-08-07 09:33:55+00:00, inspektor-gadget/inspektor-gadget::Release v0.19.0
# Added 2023-07-04 15:58:38+00:00, inspektor-gadget/inspektor-gadget::Release v0.18.1
# Added 2023-07-03 12:46:41+00:00, inspektor-gadget/inspektor-gadget::Release v0.18.0
# Added 2023-06-05 15:28:41+00:00, inspektor-gadget/inspektor-gadget::Release v0.17.0
# Added 2023-05-10 17:11:06+00:00, inspektor-gadget/inspektor-gadget::Release v0.16.1
# Added 2023-05-02 12:35:54+00:00, inspektor-gadget/inspektor-gadget::Release v0.16.0
# Added 2023-04-03 13:20:59+00:00, inspektor-gadget/inspektor-gadget::Release v0.15.0
# Added 2023-03-06 16:25:11+00:00, inspektor-gadget/inspektor-gadget::Release v0.14.0
# Added 2023-02-22 11:17:17+00:00, inspektor-gadget/inspektor-gadget::Release v0.13.1
# Added 2023-02-08 16:12:06+00:00, inspektor-gadget/inspektor-gadget::Release v0.13.0
# Added 2023-01-02 19:21:30+00:00, inspektor-gadget/inspektor-gadget::Release v0.12.1
# Added 2023-01-02 10:49:20+00:00, inspektor-gadget/inspektor-gadget::Release v0.12.0
# Added 2022-12-05 16:32:48+00:00, inspektor-gadget/inspektor-gadget::Release v0.11.0
# Added 2022-11-09 19:11:52+00:00, inspektor-gadget/inspektor-gadget::Release v0.10.0
# Added 2023-10-12 15:15:09+00:00, sustainable-computing-io/kepler::release-0.6.1
# Added 2023-10-06 12:59:29+00:00, sustainable-computing-io/kepler::release-0.6
# Added 2023-09-05 08:47:59+00:00, sustainable-computing-io/kepler::release-0.5.5
# Added 2023-08-16 23:41:03+00:00, sustainable-computing-io/kepler::release-0.5.4
# Added 2023-07-26 20:34:20+00:00, sustainable-computing-io/kepler::release-0.5.3
# Added 2023-07-21 16:37:18+00:00, sustainable-computing-io/kepler::release-0.5.2
# Added 2023-06-30 21:19:27+00:00, sustainable-computing-io/kepler::release-0.5.1
# Added 2023-06-02 09:39:00+00:00, sustainable-computing-io/kepler::release-0.5
# Added 2023-03-16 13:03:17+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 19:29:56+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 19:07:50+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:57:33+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:55:37+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:52:09+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:50:41+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:14:19+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:11:51+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-03-14 18:05:20+00:00, sustainable-computing-io/kepler::0.4.2
# Added 2023-03-14 18:04:14+00:00, sustainable-computing-io/kepler::release-0.4-standalone
# Added 2023-03-14 18:01:44+00:00, sustainable-computing-io/kepler::release-0.4-standalone
# Added 2022-12-16 20:48:56+00:00, sustainable-computing-io/kepler::release-0.4
# Added 2023-11-03 23:19:27+00:00, opencost/opencost::V1.107.0
# Added 2023-10-27 00:25:51+00:00, opencost/opencost::V1.106.4
# Added 2023-10-13 06:53:55+00:00, opencost/opencost::V1.106.3
# Added 2023-10-05 02:10:32+00:00, opencost/opencost::V1.106.2
# Added 2023-09-21 01:33:22+00:00, opencost/opencost::V1.106.1
# Added 2023-08-23 19:38:47+00:00, opencost/opencost::V1.105.2
# Added 2023-07-18 03:35:48+00:00, opencost/opencost::v1.105.0
# Added 2023-06-30 23:55:31+00:00, opencost/opencost::V1.104.4
# Added 2023-06-09 01:26:15+00:00, opencost/opencost::V1.104.0
# Added 2023-05-08 05:35:18+00:00, opencost/opencost::V1.103.1
# Added 2023-04-06 16:22:09+00:00, opencost/opencost::V1.102.0
# Added 2023-03-14 23:16:49+00:00, opencost/opencost::v1.101.2
# Added 2023-02-07 17:42:14+00:00, opencost/opencost::v1.100.0
# Added 2022-12-16 05:24:50+00:00, opencost/opencost::v1.99.0
# Added 2023-10-03 17:56:20+00:00, pixie-io/pixie::Vizier v0.14.7
# Added 2023-10-03 16:46:26+00:00, pixie-io/pixie::Vizier v0.14.7-pre-main.18
# Added 2023-10-01 17:05:26+00:00, pixie-io/pixie::Vizier v0.14.7-pre-main.0
# Added 2023-09-05 17:42:42+00:00, pixie-io/pixie::Vizier v0.14.6
# Added 2023-08-30 22:00:58+00:00, pixie-io/pixie::Vizier v0.14.6-pre-r1.0
# Added 2023-08-29 16:23:29+00:00, pixie-io/pixie::Vizier v0.14.6-pre-r0.0
# Added 2023-08-29 16:34:02+00:00, pixie-io/pixie::Operator v0.1.5-pre-r0.0
# Added 2023-08-17 21:36:15+00:00, pixie-io/pixie::Vizier v0.14.6-pre-main.0
# Added 2023-08-09 17:50:43+00:00, pixie-io/pixie::Vizier v0.14.5
# Added 2023-08-08 19:31:20+00:00, pixie-io/pixie::Vizier v0.14.5-pre-main.7
# Added 2023-08-01 23:35:01+00:00, pixie-io/pixie::Vizier v0.14.4
# Added 2023-08-01 22:59:40+00:00, pixie-io/pixie::Vizier v0.14.4-pre-main.5
# Added 2023-07-21 04:47:17+00:00, pixie-io/pixie::Vizier v0.14.3
# Added 2023-07-21 03:42:39+00:00, pixie-io/pixie::Vizier v0.14.3-pre-main.8
# Added 2023-07-20 20:25:37+00:00, pixie-io/pixie::Vizier v0.14.3-pre-r0.7
# Added 2023-07-17 17:28:45+00:00, pixie-io/pixie::Vizier v0.14.3-pre-main.4
# Added 2023-07-17 18:01:01+00:00, pixie-io/pixie::Operator v0.1.5-pre-main.11
# Added 2023-07-17 17:41:51+00:00, pixie-io/pixie::Operator v0.1.5-pre-main.10
# Added 2023-07-12 17:34:10+00:00, pixie-io/pixie::Vizier v0.14.2
# Added 2023-07-12 16:24:51+00:00, pixie-io/pixie::Cloud v0.1.7
# Added 2023-07-12 17:05:21+00:00, pixie-io/pixie::Vizier v0.14.2-pre-main.4
# Added 2023-07-10 22:28:06+00:00, pixie-io/pixie::Vizier v0.14.1
# Added 2023-06-27 19:06:51+00:00, pixie-io/pixie::Vizier v0.14.0
# Added 2023-06-27 01:28:59+00:00, pixie-io/pixie::Vizier v0.14.0-pre-roles.10
# Added 2023-06-27 16:15:37+00:00, pixie-io/pixie::Vizier v0.14.0-pre-main.10
# Added 2023-06-27 01:49:46+00:00, pixie-io/pixie::Vizier v0.13.9-pre-roles.11
# Added 2023-06-27 01:01:53+00:00, pixie-io/pixie::Vizier v0.13.9-pre-roles.10
# Added 2023-06-26 20:39:06+00:00, pixie-io/pixie::Vizier v0.13.9-pre-main.10
# Added 2023-06-23 18:51:55+00:00, pixie-io/pixie::Cloud v0.1.6
# Added 2023-06-23 18:55:05+00:00, pixie-io/pixie::Vizier v0.13.9-pre-updateTags.7
# Added 2023-06-22 20:33:00+00:00, pixie-io/pixie::Vizier v0.13.9-pre-main.4
# Added 2023-06-20 23:09:09+00:00, pixie-io/pixie::Vizier v0.13.8
# Added 2023-06-20 22:04:59+00:00, pixie-io/pixie::Operator v0.1.4
# Added 2023-06-20 18:44:21+00:00, pixie-io/pixie::Vizier v0.13.8-pre-gen-manifest-updates-from-mirrors.10
# Added 2023-06-20 20:31:13+00:00, pixie-io/pixie::Operator v0.1.4-pre-z0-1-gen-manifest-updates.1
# Added 2023-06-16 20:03:09+00:00, pixie-io/pixie::Operator v0.1.3
# Added 2023-06-14 21:28:50+00:00, pixie-io/pixie::Vizier v0.13.7
# Added 2023-06-14 20:49:28+00:00, pixie-io/pixie::Operator v0.1.2
# Added 2023-06-13 00:50:17+00:00, pixie-io/pixie::Cloud v0.1.5
# Added 2023-06-13 05:23:19+00:00, pixie-io/pixie::Cloud v0.1.4
# Added 2023-06-02 18:02:29+00:00, pixie-io/pixie::Cloud v0.1.3
# Added 2023-05-31 20:58:10+00:00, pixie-io/pixie::Vizier v0.13.6
# Added 2023-05-31 21:07:42+00:00, pixie-io/pixie::Cloud v0.1.2
# Added 2023-05-30 18:55:28+00:00, pixie-io/pixie::CLI v0.8.2
# Added 2023-05-25 18:34:03+00:00, pixie-io/pixie::CLI v0.8.1
# Added 2023-05-23 20:29:46+00:00, pixie-io/pixie::Vizier v0.13.5
# Added 2023-05-23 20:47:45+00:00, pixie-io/pixie::Operator v0.1.1
# Added 2023-05-22 20:39:58+00:00, pixie-io/pixie::Vizier v0.13.4
# Added 2023-05-17 22:27:45+00:00, pixie-io/pixie::Vizier v0.13.3
# Added 2023-05-16 23:12:58+00:00, pixie-io/pixie::Cloud v0.1.1
# Added 2023-05-11 04:06:07+00:00, pixie-io/pixie::Cloud v0.1.0
# Added 2023-05-11 21:03:32+00:00, pixie-io/pixie::CLI v0.8.0
# Added 2023-05-09 22:35:24+00:00, pixie-io/pixie::Vizier v0.13.2

# %% [markdown]
# ## Visualize Releases

# %%
# %pip install ipympl

# %matplotlib inline
# %matplotlib widget

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# def plot_releases_timeline(releases: pd.DataFrame):
#     fig = px.timeline(releases, x_start="release_date", x_end="release_date", y="repo_name", color="language", title="GitHub Releases Timeline")
#     fig.update_yaxes(autorange="reversed")
#     fig.show()

# def plot_releases_scatter_simple(releases: pd.DataFrame):
#     # Filter releases by year
#     releases_2023 = releases[releases['release_date'].dt.year == 2023]

#     # Create scatter plot
#     fig = px.scatter(releases_2023, x="release_date", y="repo_name", color="language")
#     fig.update_yaxes(autorange="reversed")
#     fig.show()

def plot_releases_scatter(releases: pd.DataFrame, title: str=None):
    # # Filter releases by year
    # releases_2023 = releases[releases['release_date'].dt.year == 2023]

    if title is None:
        title = "GitHub Releases Timeline"

    # Group releases by organization
    releases['organization'] = releases['repo_name'].apply(lambda x: x.split('/')[0])

    # Create scatter plot
    fig = px.scatter(releases, x="release_date", y="repo_name", color="organization", symbol="language", title="Project Releases")
    fig.update_yaxes(autorange="reversed")
    
    fig.update_layout(showlegend=True,
                      autosize=True,
                      width=1000)
                    #   height=2500,
                    #   )
    fig.show()

# %%
import pandas as pd
import os

def json_to_csv(json_file_path: str) -> None:
    """
    Load a JSON file into a pandas DataFrame and save it as a CSV file with the same name.
    """
    df = pd.read_json(json_file_path, lines=True)
    
    csv_file_path = os.path.splitext(json_file_path)[0] + '.csv'
    df.to_csv(csv_file_path, index=False)

# %%
for level in ['graduated', 'incubating', 'sandbox']:
    json_to_csv(f'out/cncf-{level}-github-releases.json')

# %%
def plot_releases_from_csv(csv_file: str, title: str) -> None:
    csv_file =f'out/cncf-{level}-github-releases.csv'
    if os.path.exists(csv_file):
        df_releases = pd.read_csv(csv_file)
        df_releases.release_date = pd.to_datetime(df_releases.release_date)
        
        plot_releases_scatter(df_releases, title)
    else:
        print(f"CSV file {csv_file} not found")

# %%
import pandas as pd
import os

for level in ['graduated', 'incubating', 'sandbox']:
    plot_releases_from_csv(f'out/cncf-{level}-github-releases.csv', f'Releases: {level}')

# %%
import pandas as pd
import os


# plot_releases_scatter(f'out/cncf-all-github-releases.csv')

# %%
releases_by_repo = releases[['repo_name', 'release_date']].groupby('repo_name').count()
releases_by_repo.to_csv('cncf_releases_by_repo.csv')
