# %% [markdown]
# # Fetch all GitHub Release info for CNCF projects

# %% [markdown]
# ## install dependencies

# %%
# %pip list | grep -E 'pandas|dask|sqlalchemy|psycopg2-binary|graphviz|PyGitHub|opentelemetry-api|opentelemetry-sdk|python-dotenv|jsonpath-ng'
# %pip install pandas dask sqlalchemy psycopg2-binary graphviz PyGitHub opentelemetry-api opentelemetry-sdk python-dotenv jsonpath-ng
# Out:
# dask                               2023.10.0
# dask_labextension                  7.0.0
# jsonpath-ng                        1.6.0
# opentelemetry-api                  1.20.0
# opentelemetry-sdk                  1.20.0
# pandas                             2.0.3
# psycopg2-binary                    2.9.9
# python-dotenv                      1.0.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: dask in /opt/conda/lib/python3.11/site-packages (2023.10.0)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.11/site-packages (2.0.22)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.11/site-packages (2.9.9)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: PyGitHub in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: opentelemetry-api in /opt/conda/lib/python3.11/site-packages (1.20.0)
# Requirement already satisfied: opentelemetry-sdk in /opt/conda/lib/python3.11/site-packages (1.20.0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: jsonpath-ng in /opt/conda/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from dask) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.11/site-packages (from dask) (2023.9.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from dask) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from dask) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from dask) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.11/site-packages (from dask) (6.8.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (3.0.0)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from PyGitHub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /opt/conda/lib/python3.11/site-packages (from PyGitHub) (2.31.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->PyGitHub) (2.8.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from PyGitHub) (2.0.7)
# Requirement already satisfied: Deprecated in /opt/conda/lib/python3.11/site-packages (from PyGitHub) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.41b0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk) (0.41b0)
# Requirement already satisfied: ply in /opt/conda/lib/python3.11/site-packages (from jsonpath-ng) (3.11)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.11/site-packages (from Deprecated->PyGitHub) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: locket in /opt/conda/lib/python3.11/site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->PyGitHub) (41.0.4)
# Requirement already satisfied: cffi>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from pynacl>=1.4.0->PyGitHub) (1.16.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.14.0->PyGitHub) (2023.7.22)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGitHub) (2.21)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list | grep -E 'pandas|dask|sqlalchemy|psycopg2-binary|graphvizPy|GitHub|opentelemetry-api|opentelemetry-sdk|python-dotenv|jsonpath-ng'
# Out:
# dask                               2023.10.0
# dask_labextension                  7.0.0
# jsonpath-ng                        1.6.0
# opentelemetry-api                  1.20.0
# opentelemetry-sdk                  1.20.0
# pandas                             2.0.3
# psycopg2-binary                    2.9.9
# python-dotenv                      1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import json
from datetime import datetime, timezone

import pandas as pd
from typing import List
from github import Github, GithubException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

# for PAT / token
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Load OSRB repo list

# %%
def safe_set_index(df:         pd.DataFrame, 
                   idx_wanted: list[str]) -> pd.DataFrame:

    # check to see if the index is already set, else, data loss as set_index can be destructive
    idx_existing = list(df.index.names)

    if idx_wanted == idx_existing:
        print(f'\n*** WARNING: attempt to set index to what it already is thwarted! \n')
    else:
        df.set_index(idx_wanted, verify_integrity=True, inplace=True) # note: index must be unique!
        df.sort_index(inplace=True, ascending=True)
    return df

def split_org_repo(df:               pd.DataFrame, 
                   colname:          str,
                   drop:             bool = False,
                   newcol_org_name:  str = 'org_name',
                   newcol_repo_name: str = 'repo_name',
                   multi_idx:        bool = False) -> pd.DataFrame:
    '''split_org_repo(df, colname) - org_name/repo_name --> org_name, repo_named'''
    
    if colname is None:
        raise ValueError('split_org_repo: missing colname!')

    # df['tmp'] = df[colname].copy()
    # df_newcols = df['tmp'].str.split(pat='/', n=1, expand=True)

    # https://swdevnotes.com/python/2022/extract-data-from-json-in-pandas-dataframe/
    # expand=True returns a dataframe  which we can rename columns on
    df_newcols = df[colname].copy().str.split(pat='/', n=1, expand=True)
    df_newcols.rename(columns={0: newcol_org_name, 1: newcol_repo_name}, inplace=True)

    if drop:
        df.drop(colname, axis=1, inplace=True)

    df = pd.concat([df,df_newcols], axis=1)

    if multi_idx:
        safe_set_index(df, idx_wanted=[newcol_org_name, newcol_repo_name])
    else:
        safe_set_index(df, idx_wanted=[colname])

    return df

#############

def load_repos(fname: str=None, splitcols: bool=False, lowercase: bool=False) -> pd.DataFrame:
    '''Load repos from a file'''

    with open(fname, 'r') as f:
        df = pd.DataFrame(f.readlines(), columns=['name'])

    # strip comments (note '~' negation in selector)
    df = df[~df['name'].astype(str).str.startswith('#')]

    # clean up trailing newlines and where OSRB API returns a trailing slash
    df.name = df.name.str.rstrip(to_strip='\n')
    df.name = df.name.str.rstrip(to_strip='/')

    if lowercase:
        df.name = df.name.str.lower()

    # {name: someOrg/someRepo} --> { name: 'someOrg/someRepo', org_name = 'someOrg', repo_name = 'someRepo'
    if splitcols:
        df = split_org_repo(df, colname='name', multi_idx=True)
    else:
        # split_org_repo handles setting the index and sorting
        safe_set_index(df, idx_wanted=['name'])
    return df

# %%
OSRB_FILE = '../../data/osrb/osrb-repos.txt'
#OSRB_FILE = '../../data/osrb/osrb-repos-debugsmall.txt'

osrb = load_repos(OSRB_FILE, lowercase=True)
display(osrb.head())

osrb_split = load_repos(OSRB_FILE, splitcols=True, lowercase=True)
display(osrb_split)

osrb_split.groupby('org_name').count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [academysoftwarefoundation/materialx, academysoftwarefoundation/opencolorio, academysoftwarefoundation/opencue/tree/master, academysoftwarefoundation/openexr, academysoftwarefoundation/openvdb]
#                                                                                                    name
# org_name                  repo_name
# academysoftwarefoundation materialx                                 academysoftwarefoundation/materialx
#                           opencolorio                             academysoftwarefoundation/opencolorio
#                           opencue/tree/master             academysoftwarefoundation/opencue/tree/master
#                           openexr                                     academysoftwarefoundation/openexr
#                           openvdb                                     academysoftwarefoundation/openvdb
#                           rez                                             academysoftwarefoundation/rez
# apache                    airflow                                                        apache/airflow
#                           arrow                                                            apache/arrow
#                           cassandra                                                    apache/cassandra
#                           cloudstack                                                  apache/cloudstack
#                           druid                                                            apache/druid
#                           flink                                                            apache/flink
#                           flume                                                            apache/flume
#                           hadoop                                                          apache/hadoop
#                           hbase                                                            apache/hbase
#                           hive                                                              apache/hive
#                           iceberg                                                        apache/iceberg
#                           incubator-toree                                        apache/incubator-toree
#                           kafka                                                            apache/kafka
#                           kyuubi                                                          apache/kyuubi
#                           logging-log4j2                                          apache/logging-log4j2
#                           lucene                                                          apache/lucene
#                           orc                                                                apache/orc
#                           ozone                                                            apache/ozone
#                           parquet-mr                                                  apache/parquet-mr
#                           solr                                                              apache/solr
#                           spark                                                            apache/spark
#                           superset                                                      apache/superset
#                           trafficserver                                            apache/trafficserver
#                           yunikorn-core                                            apache/yunikorn-core
#                           zookeeper                                                    apache/zookeeper
# apple                     app-store-server-library-swift           apple/app-store-server-library-swift
#                           batch-processing-gateway                       apple/batch-processing-gateway
#                           coremltools                                                 apple/coremltools
#                           darwin-libplatform                                   apple/darwin-libplatform
#                           fhirmodels                                                   apple/fhirmodels
#                           foundationdb                                               apple/foundationdb
#                           gcgc                                                               apple/gcgc
#                           password-manager-resources                   apple/password-manager-resources
#                           servicetalk                                                 apple/servicetalk
#                           swift                                                             apple/swift
#                           swift-corelibs-foundation                     apple/swift-corelibs-foundation
#                           swift-corelibs-libdispatch                   apple/swift-corelibs-libdispatch
#                           swift-crypto                                               apple/swift-crypto
#                           swift-distributed-actors                       apple/swift-distributed-actors
#                           swift-distributed-tracing                     apple/swift-distributed-tracing
#                           swift-log                                                     apple/swift-log
#                           swift-metrics                                             apple/swift-metrics
#                           swift-nio                                                     apple/swift-nio
#                           swift-protobuf                                           apple/swift-protobuf
#                           swift-service-discovery                         apple/swift-service-discovery
#                           turicreate                                                   apple/turicreate
# autodesk                  maya-usd                                                    autodesk/maya-usd
# aws                       karpenter                                                       aws/karpenter
# bazelbuild                bazel                                                        bazelbuild/bazel
# benchopt                  benchopt                                                    benchopt/benchopt
# boostorg                  boost                                                          boostorg/boost
# buildbarn                 NaN                                                                 buildbarn
# buildbot                  buildbot                                                    buildbot/buildbot
# carekit-apple             carekit                                                 carekit-apple/carekit
# cilium                    cilium                                                          cilium/cilium
# cloud-hypervisor          cloud-hypervisor                            cloud-hypervisor/cloud-hypervisor
# cloudflare                quiche                                                      cloudflare/quiche
# containerd                containerd                                              containerd/containerd
# crossplane                crossplane                                              crossplane/crossplane
# datastax                  java-driver                                              datastax/java-driver
# definitelytyped           definitelytyped                               definitelytyped/definitelytyped
# delta-io                  delta                                                          delta-io/delta
# dropwizard                dropwizard                                              dropwizard/dropwizard
# elyra-ai                  elyra                                                          elyra-ai/elyra
# envoyproxy                envoy                                                        envoyproxy/envoy
# etcd-io                   etcd                                                             etcd-io/etcd
# falcosecurity             falco                                                     falcosecurity/falco
# filodb                    filodb                                                          filodb/filodb
# gnome                     libxml2                                                         gnome/libxml2
#                           libxslt                                                         gnome/libxslt
# google                    angle                                                            google/angle
#                           boringssl                                                    google/boringssl
#                           data-transfer-project                            google/data-transfer-project
#                           jax                                                                google/jax
# googlecloudplatform       spark-on-k8s-operator               googlecloudplatform/spark-on-k8s-operator
# goss-org                  goss                                                            goss-org/goss
# gradle                    NaN                                                                    gradle
# grpc                      grpc-swift                                                    grpc/grpc-swift
# hotosm                    tasking-manager                                        hotosm/tasking-manager
# isabelle-prover           NaN                                                           isabelle-prover
# istio                     istio                                                             istio/istio
# jetstack                  cert-manager                                            jetstack/cert-manager
# jupyter                   NaN                                                                   jupyter
# jupyter-server            enterprise_gateway                          jupyter-server/enterprise_gateway
# kata-containers           kata-containers                               kata-containers/kata-containers
# kubeflow                  kubeflow                                                    kubeflow/kubeflow
# kubernetes                kubernetes                                              kubernetes/kubernetes
# kubevirt                  kubevirt                                                    kubevirt/kubevirt
# lzfse                     lzfse                                                             lzfse/lzfse
# machyve                   xhyve                                                           machyve/xhyve
# maproulette               maproulette2                                         maproulette/maproulette2
# microsoft                 typescript                                               microsoft/typescript
# multipath-tcp             mptcp                                                     multipath-tcp/mptcp
# netty                     netty                                                             netty/netty
# open-policy-agent         opa                                                     open-policy-agent/opa
# open-telemetry            opentelemetry.io                              open-telemetry/opentelemetry.io
# osmlab                    atlas                                                            osmlab/atlas
# osquery                   osquery                                                       osquery/osquery
# pixaranimationstudios     usd                                                 pixaranimationstudios/usd
# playframework             playframework                                     playframework/playframework
# prometheus                prometheus                                              prometheus/prometheus
# pulumi                    pulumi                                                          pulumi/pulumi
# pytorch                   pytorch                                                       pytorch/pytorch
# qemu                      qemu                                                                qemu/qemu
# researchkit               researchkit                                           researchkit/researchkit
# scverse                   scanpy                                                         scverse/scanpy
# seleniumhq                selenium                                                  seleniumhq/selenium
# spinnaker                 spinnaker                                                 spinnaker/spinnaker
# strimzi                   strimzi-kafka-operator                         strimzi/strimzi-kafka-operator
# swift-server              swift-aws-lambda-runtime                swift-server/swift-aws-lambda-runtime
#                           swift-backtrace                                  swift-server/swift-backtrace
# tektoncd                  NaN                                                                  tektoncd
# temporalio                temporal                                                  temporalio/temporal
# theislab                  moscot                                                        theislab/moscot
# trinodb                   trino                                                           trinodb/trino
# uber                      remoteshuffleservice                                uber/remoteshuffleservice
# vega                      vega                                                                vega/vega
#                            name
# org_name
# academysoftwarefoundation     6
# apache                       25
# apple                        21
# autodesk                      1
# aws                           1
# bazelbuild                    1
# benchopt                      1
# boostorg                      1
# buildbarn                     1
# buildbot                      1
# carekit-apple                 1
# cilium                        1
# cloud-hypervisor              1
# cloudflare                    1
# containerd                    1
# crossplane                    1
# datastax                      1
# definitelytyped               1
# delta-io                      1
# dropwizard                    1
# elyra-ai                      1
# envoyproxy                    1
# etcd-io                       1
# falcosecurity                 1
# filodb                        1
# gnome                         2
# google                        4
# googlecloudplatform           1
# goss-org                      1
# gradle                        1
# grpc                          1
# hotosm                        1
# isabelle-prover               1
# istio                         1
# jetstack                      1
# jupyter                       1
# jupyter-server                1
# kata-containers               1
# kubeflow                      1
# kubernetes                    1
# kubevirt                      1
# lzfse                         1
# machyve                       1
# maproulette                   1
# microsoft                     1
# multipath-tcp                 1
# netty                         1
# open-policy-agent             1
# open-telemetry                1
# osmlab                        1
# osquery                       1
# pixaranimationstudios         1
# playframework                 1
# prometheus                    1
# pulumi                        1
# pytorch                       1
# qemu                          1
# researchkit                   1
# scverse                       1
# seleniumhq                    1
# spinnaker                     1
# strimzi                       1
# swift-server                  2
# tektoncd                      1
# temporalio                    1
# theislab                      1
# trinodb                       1
# uber                          1
# vega                          1

# %% [markdown]
# ## Fetch project high level metadata from GitHub API

# %%
import time
import json
import pandas as pd
from typing import List, Tuple
from datetime import datetime, timezone
from github import Github, GithubException
from jsonpath_ng import parse

def fetch_repo_data(token: str, 
                    repo_list: List[str], 
                    include_releases: bool=False,
                    releases_since: datetime=None, 
                    json_file: str=None, 
                    csv_file: str=None, 
                    state_file: str=None, 
                    properties: List[Tuple[str, str]]=None) -> pd.DataFrame:

    # Initialize DataFrame
    df = pd.DataFrame()

    # Initialize GitHub client
    g = Github(token)

    # Initialize loop state
    if state_file:
        try:
            with open(state_file, 'r') as f:
                state = json.load(f)
        except FileNotFoundError:
            state = {'i': 0, 'repos_done': []}
    else:
        state = {'i': 0, 'repos_done': []}

    while state['i'] < len(repo_list):
        repo_str = repo_list[state['i']]

        # Skip repository if already done
        if repo_str in state['repos_done']:
            print(f"Skipping {repo_str}")
            state['i'] += 1
            continue

        while True:
            try:
                repo = g.get_repo(repo_str)
                break
            except GithubException as e:
                if e.status == 404:
                    print(f"Repository {repo_str} not found")
                    break
                elif e.status == 429:
                    print(f"Rate limit exceeded, waiting for {e.headers['Retry-After']} seconds...")
                    time.sleep(int(e.headers['Retry-After']))
                else:
                    print(f"Error getting repository {repo_str}: {e}")
                    break

        if not repo:
            state['i'] += 1
            continue

        print(f"{repo_str} Fetching Metadata...")
        repo_dict = repo.raw_data

        if properties is None:
            # Add all properties to DataFrame
            df = pd.concat([df, pd.json_normalize(repo_dict)])
        else:
            # Add specific (and specified!) properties to DataFrame
            for prop_path, col_name in properties:
                jsonpath_expr = parse(prop_path)
                matches = jsonpath_expr.find(repo_dict)
                values = [match.value for match in matches]
                df[col_name] = values

        if include_releases:
            releases = repo.get_releases()
            for release in releases:
                if since is None or release.created_at >= since:
                    df = pd.concat([df, pd.DataFrame({
                        'repo_name': [repo_str],
                        'release_name': [release.title],
                        'release_date': [str(release.published_at)],
                        'language': [repo.language],
                        'release_notes': [release.body],
                        'stars': [repo.stargazers_count],
                        'forks': [repo.forks_count],
                        'open_issues': [repo.open_issues_count]
                    })])
                    print(f"Added {release.published_at}, {repo_str}::{release.title}  ")

        # Save state
        if state_file:
            state['repos_done'].append(repo_str)
            with open(state_file, 'w') as f:
                json.dump(state, f, indent=4)

        state['i'] += 1

    # Save as CSV
    if csv_file:
        df.to_csv(csv_file, index=False)

    # Save as JSON
    if json_file:
        # with open(json_file, 'w') as f:
        #     json.dump(df.to_dict(orient='records', f, indent=4)
        df.to_json(json_file, orient='records', indent=4, lines=True)

    return df

# %% [markdown]
# ## Get repo metadata from GitHub (REST) API

# %%
osrb.reset_index(inplace=False).name.to_list()
# Out:
# ['academysoftwarefoundation/materialx',
#  'academysoftwarefoundation/opencolorio',
#  'academysoftwarefoundation/opencue/tree/master',
#  'academysoftwarefoundation/openexr',
#  'academysoftwarefoundation/openvdb',
#  'academysoftwarefoundation/rez',
#  'apache/airflow',
#  'apache/arrow',
#  'apache/cassandra',
#  'apache/cloudstack',
#  'apache/druid',
#  'apache/flink',
#  'apache/flume',
#  'apache/hadoop',
#  'apache/hbase',
#  'apache/hive',
#  'apache/iceberg',
#  'apache/incubator-toree',
#  'apache/kafka',
#  'apache/kyuubi',
#  'apache/logging-log4j2',
#  'apache/lucene',
#  'apache/orc',
#  'apache/ozone',
#  'apache/parquet-mr',
#  'apache/solr',
#  'apache/spark',
#  'apache/superset',
#  'apache/trafficserver',
#  'apache/yunikorn-core',
#  'apache/zookeeper',
#  'apple/app-store-server-library-swift',
#  'apple/batch-processing-gateway',
#  'apple/coremltools',
#  'apple/darwin-libplatform',
#  'apple/fhirmodels',
#  'apple/foundationdb',
#  'apple/gcgc',
#  'apple/password-manager-resources',
#  'apple/servicetalk',
#  'apple/swift',
#  'apple/swift-corelibs-foundation',
#  'apple/swift-corelibs-libdispatch',
#  'apple/swift-crypto',
#  'apple/swift-distributed-actors',
#  'apple/swift-distributed-tracing',
#  'apple/swift-log',
#  'apple/swift-metrics',
#  'apple/swift-nio',
#  'apple/swift-protobuf',
#  'apple/swift-service-discovery',
#  'apple/turicreate',
#  'autodesk/maya-usd',
#  'aws/karpenter',
#  'bazelbuild/bazel',
#  'benchopt/benchopt',
#  'boostorg/boost',
#  'buildbarn',
#  'buildbot/buildbot',
#  'carekit-apple/carekit',
#  'cilium/cilium',
#  'cloud-hypervisor/cloud-hypervisor',
#  'cloudflare/quiche',
#  'containerd/containerd',
#  'crossplane/crossplane',
#  'datastax/java-driver',
#  'definitelytyped/definitelytyped',
#  'delta-io/delta',
#  'dropwizard/dropwizard',
#  'elyra-ai/elyra',
#  'envoyproxy/envoy',
#  'etcd-io/etcd',
#  'falcosecurity/falco',
#  'filodb/filodb',
#  'gnome/libxml2',
#  'gnome/libxslt',
#  'google/angle',
#  'google/boringssl',
#  'google/data-transfer-project',
#  'google/jax',
#  'googlecloudplatform/spark-on-k8s-operator',
#  'goss-org/goss',
#  'gradle',
#  'grpc/grpc-swift',
#  'hotosm/tasking-manager',
#  'isabelle-prover',
#  'istio/istio',
#  'jetstack/cert-manager',
#  'jupyter',
#  'jupyter-server/enterprise_gateway',
#  'kata-containers/kata-containers',
#  'kubeflow/kubeflow',
#  'kubernetes/kubernetes',
#  'kubevirt/kubevirt',
#  'lzfse/lzfse',
#  'machyve/xhyve',
#  'maproulette/maproulette2',
#  'microsoft/typescript',
#  'multipath-tcp/mptcp',
#  'netty/netty',
#  'open-policy-agent/opa',
#  'open-telemetry/opentelemetry.io',
#  'osmlab/atlas',
#  'osquery/osquery',
#  'pixaranimationstudios/usd',
#  'playframework/playframework',
#  'prometheus/prometheus',
#  'pulumi/pulumi',
#  'pytorch/pytorch',
#  'qemu/qemu',
#  'researchkit/researchkit',
#  'scverse/scanpy',
#  'seleniumhq/selenium',
#  'spinnaker/spinnaker',
#  'strimzi/strimzi-kafka-operator',
#  'swift-server/swift-aws-lambda-runtime',
#  'swift-server/swift-backtrace',
#  'tektoncd',
#  'temporalio/temporal',
#  'theislab/moscot',
#  'trinodb/trino',
#  'uber/remoteshuffleservice',
#  'vega/vega']

# %%
import os

repos = osrb.reset_index(inplace=False).name.to_list()
since_date = datetime(2023, 1, 1, tzinfo=timezone.utc)

fnbase = 'osrb-repo-summary'
json_file = f'{fnbase}.json'
csv_file = f'{fnbase}.csv'
state_file = f'{fnbase}.state.json'

repodata = fetch_repo_data(os.environ['GITHUB_TOKEN'], 
                           repos,
                           include_releases=False,
                           releases_since=since_date, 
                           json_file=json_file, 
                           csv_file=csv_file)

                           #state_file=state_file

print(repodata.info(show_counts=True))
display(repodata.head())
# Out:
# academysoftwarefoundation/materialx Fetching Metadata...
# academysoftwarefoundation/opencolorio Fetching Metadata...
# Repository academysoftwarefoundation/opencue/tree/master not found
# academysoftwarefoundation/opencue/tree/master Fetching Metadata...
# academysoftwarefoundation/openexr Fetching Metadata...
# academysoftwarefoundation/openvdb Fetching Metadata...
# academysoftwarefoundation/rez Fetching Metadata...
# apache/airflow Fetching Metadata...
# apache/arrow Fetching Metadata...
# apache/cassandra Fetching Metadata...
# apache/cloudstack Fetching Metadata...
# apache/druid Fetching Metadata...
# apache/flink Fetching Metadata...
# apache/flume Fetching Metadata...
# apache/hadoop Fetching Metadata...
# apache/hbase Fetching Metadata...
# apache/hive Fetching Metadata...
# apache/iceberg Fetching Metadata...
# apache/incubator-toree Fetching Metadata...
# apache/kafka Fetching Metadata...
# apache/kyuubi Fetching Metadata...
# apache/logging-log4j2 Fetching Metadata...
# apache/lucene Fetching Metadata...
# apache/orc Fetching Metadata...
# apache/ozone Fetching Metadata...
# apache/parquet-mr Fetching Metadata...
# apache/solr Fetching Metadata...
# apache/spark Fetching Metadata...
# apache/superset Fetching Metadata...
# apache/trafficserver Fetching Metadata...
# apache/yunikorn-core Fetching Metadata...
# apache/zookeeper Fetching Metadata...
# apple/app-store-server-library-swift Fetching Metadata...
# apple/batch-processing-gateway Fetching Metadata...
# apple/coremltools Fetching Metadata...
# apple/darwin-libplatform Fetching Metadata...
# apple/fhirmodels Fetching Metadata...
# apple/foundationdb Fetching Metadata...
# apple/gcgc Fetching Metadata...
# apple/password-manager-resources Fetching Metadata...
# apple/servicetalk Fetching Metadata...
# apple/swift Fetching Metadata...
# apple/swift-corelibs-foundation Fetching Metadata...
# apple/swift-corelibs-libdispatch Fetching Metadata...
# apple/swift-crypto Fetching Metadata...
# apple/swift-distributed-actors Fetching Metadata...
# apple/swift-distributed-tracing Fetching Metadata...
# apple/swift-log Fetching Metadata...
# apple/swift-metrics Fetching Metadata...
# apple/swift-nio Fetching Metadata...
# apple/swift-protobuf Fetching Metadata...
# apple/swift-service-discovery Fetching Metadata...
# apple/turicreate Fetching Metadata...
# autodesk/maya-usd Fetching Metadata...
# aws/karpenter Fetching Metadata...
# bazelbuild/bazel Fetching Metadata...
# benchopt/benchopt Fetching Metadata...
# boostorg/boost Fetching Metadata...
# Repository buildbarn not found
# buildbarn Fetching Metadata...
# buildbot/buildbot Fetching Metadata...
# carekit-apple/carekit Fetching Metadata...
# cilium/cilium Fetching Metadata...
# cloud-hypervisor/cloud-hypervisor Fetching Metadata...
# cloudflare/quiche Fetching Metadata...
# containerd/containerd Fetching Metadata...
# crossplane/crossplane Fetching Metadata...
# datastax/java-driver Fetching Metadata...
# definitelytyped/definitelytyped Fetching Metadata...
# delta-io/delta Fetching Metadata...
# dropwizard/dropwizard Fetching Metadata...
# elyra-ai/elyra Fetching Metadata...
# envoyproxy/envoy Fetching Metadata...
# etcd-io/etcd Fetching Metadata...
# falcosecurity/falco Fetching Metadata...
# filodb/filodb Fetching Metadata...
# gnome/libxml2 Fetching Metadata...
# gnome/libxslt Fetching Metadata...
# google/angle Fetching Metadata...
# google/boringssl Fetching Metadata...
# google/data-transfer-project Fetching Metadata...
# google/jax Fetching Metadata...
# googlecloudplatform/spark-on-k8s-operator Fetching Metadata...
# goss-org/goss Fetching Metadata...
# Repository gradle not found
# gradle Fetching Metadata...
# grpc/grpc-swift Fetching Metadata...
# hotosm/tasking-manager Fetching Metadata...
# Repository isabelle-prover not found
# isabelle-prover Fetching Metadata...
# istio/istio Fetching Metadata...
# Following Github server redirection from /repos/jetstack/cert-manager to /repositories/92313258
# jetstack/cert-manager Fetching Metadata...
# Repository jupyter not found
# jupyter Fetching Metadata...
# jupyter-server/enterprise_gateway Fetching Metadata...
# kata-containers/kata-containers Fetching Metadata...
# kubeflow/kubeflow Fetching Metadata...
# kubernetes/kubernetes Fetching Metadata...
# kubevirt/kubevirt Fetching Metadata...
# lzfse/lzfse Fetching Metadata...
# machyve/xhyve Fetching Metadata...
# Following Github server redirection from /repos/maproulette/maproulette2 to /repositories/53699564
# maproulette/maproulette2 Fetching Metadata...
# microsoft/typescript Fetching Metadata...
# multipath-tcp/mptcp Fetching Metadata...
# netty/netty Fetching Metadata...
# open-policy-agent/opa Fetching Metadata...
# open-telemetry/opentelemetry.io Fetching Metadata...
# osmlab/atlas Fetching Metadata...
# osquery/osquery Fetching Metadata...
# Following Github server redirection from /repos/pixaranimationstudios/usd to /repositories/58168143
# pixaranimationstudios/usd Fetching Metadata...
# playframework/playframework Fetching Metadata...
# prometheus/prometheus Fetching Metadata...
# pulumi/pulumi Fetching Metadata...
# pytorch/pytorch Fetching Metadata...
# qemu/qemu Fetching Metadata...
# researchkit/researchkit Fetching Metadata...
# scverse/scanpy Fetching Metadata...
# seleniumhq/selenium Fetching Metadata...
# spinnaker/spinnaker Fetching Metadata...
# strimzi/strimzi-kafka-operator Fetching Metadata...
# swift-server/swift-aws-lambda-runtime Fetching Metadata...
# swift-server/swift-backtrace Fetching Metadata...
# Repository tektoncd not found
# tektoncd Fetching Metadata...
# temporalio/temporal Fetching Metadata...
# theislab/moscot Fetching Metadata...
# trinodb/trino Fetching Metadata...
# uber/remoteshuffleservice Fetching Metadata...
# vega/vega Fetching Metadata...
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 0 to 0
# Columns: 126 entries, id to license
# dtypes: bool(20), int64(13), object(93)
# memory usage: 109.3+ KB
# None
#          id                           node_id         name                              full_name  private  \
# 0  96365647  MDEwOlJlcG9zaXRvcnk5NjM2NTY0Nw==    MaterialX    AcademySoftwareFoundation/MaterialX    False
# 0    775131      MDEwOlJlcG9zaXRvcnk3NzUxMzE=  OpenColorIO  AcademySoftwareFoundation/OpenColorIO    False
# 0    775131      MDEwOlJlcG9zaXRvcnk3NzUxMzE=  OpenColorIO  AcademySoftwareFoundation/OpenColorIO    False
# 0   3533348      MDEwOlJlcG9zaXRvcnkzNTMzMzQ4      openexr      AcademySoftwareFoundation/openexr    False
# 0   9401161      MDEwOlJlcG9zaXRvcnk5NDAxMTYx      openvdb      AcademySoftwareFoundation/openvdb    False
#
#                                             html_url                                        description   fork  \
# 0  https://github.com/AcademySoftwareFoundation/M...  MaterialX is an open standard for the exchange...  False
# 0  https://github.com/AcademySoftwareFoundation/O...  A color management framework for visual effect...  False
# 0  https://github.com/AcademySoftwareFoundation/O...  A color management framework for visual effect...  False
# 0  https://github.com/AcademySoftwareFoundation/o...  The OpenEXR project provides the specification...  False
# 0  https://github.com/AcademySoftwareFoundation/o...   OpenVDB - Sparse volume data structure and tools  False
#
#                                                  url                                          forks_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                             keys_url                                  collaborators_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                            teams_url                                          hooks_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                     issue_events_url                                         events_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                        assignees_url                                       branches_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                             tags_url                                          blobs_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                         git_tags_url                                       git_refs_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                            trees_url                                       statuses_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                        languages_url                                     stargazers_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                     contributors_url                                    subscribers_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                     subscription_url                                        commits_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                      git_commits_url                                       comments_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                    issue_comment_url                                       contents_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                          compare_url                                         merges_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                          archive_url                                      downloads_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                           issues_url                                          pulls_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                       milestones_url                                  notifications_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                           labels_url                                       releases_url  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
# 0  https://api.github.com/repos/AcademySoftwareFo...  https://api.github.com/repos/AcademySoftwareFo...
#
#                                      deployments_url            created_at            updated_at             pushed_at  \
# 0  https://api.github.com/repos/AcademySoftwareFo...  2017-07-05T22:18:25Z  2023-10-27T16:28:17Z  2023-10-28T00:29:32Z
# 0  https://api.github.com/repos/AcademySoftwareFo...  2010-07-14T18:22:06Z  2023-10-27T05:57:50Z  2023-10-27T22:56:44Z
# 0  https://api.github.com/repos/AcademySoftwareFo...  2010-07-14T18:22:06Z  2023-10-27T05:57:50Z  2023-10-27T22:56:44Z
# 0  https://api.github.com/repos/AcademySoftwareFo...  2012-02-24T06:30:00Z  2023-10-25T18:00:03Z  2023-10-25T02:27:38Z
# 0  https://api.github.com/repos/AcademySoftwareFo...  2013-04-12T18:39:57Z  2023-10-27T22:04:39Z  2023-10-27T23:20:20Z
#
#                                              git_url                                            ssh_url  \
# 0  git://github.com/AcademySoftwareFoundation/Mat...  git@github.com:AcademySoftwareFoundation/Mater...
# 0  git://github.com/AcademySoftwareFoundation/Ope...  git@github.com:AcademySoftwareFoundation/OpenC...
# 0  git://github.com/AcademySoftwareFoundation/Ope...  git@github.com:AcademySoftwareFoundation/OpenC...
# 0  git://github.com/AcademySoftwareFoundation/ope...  git@github.com:AcademySoftwareFoundation/opene...
# 0  git://github.com/AcademySoftwareFoundation/ope...  git@github.com:AcademySoftwareFoundation/openv...
#
#                                            clone_url                                            svn_url                   homepage    size  \
# 0  https://github.com/AcademySoftwareFoundation/M...  https://github.com/AcademySoftwareFoundation/M...  http://www.materialx.org/  197226
# 0  https://github.com/AcademySoftwareFoundation/O...  https://github.com/AcademySoftwareFoundation/O...    https://opencolorio.org   62811
# 0  https://github.com/AcademySoftwareFoundation/O...  https://github.com/AcademySoftwareFoundation/O...    https://opencolorio.org   62811
# 0  https://github.com/AcademySoftwareFoundation/o...  https://github.com/AcademySoftwareFoundation/o...    http://www.openexr.com/   53344
# 0  https://github.com/AcademySoftwareFoundation/o...  https://github.com/AcademySoftwareFoundation/o...    http://www.openvdb.org/   54198
#
#    stargazers_count  watchers_count language  has_issues  has_projects  has_downloads  has_wiki  has_pages  has_discussions  forks_count mirror_url  \
# 0              1590            1590      C++        True          True           True      True       True            False          308       None
# 0              1603            1603      C++        True          True           True      True       True            False          404       None
# 0              1603            1603      C++        True          True           True      True       True            False          404       None
# 0              1504            1504        C        True          True           True      True      False            False          574       None
# 0              2267            2267      C++        True          True           True     False       True             True          593       None
#
#    archived  disabled  open_issues_count  allow_forking  is_template  web_commit_signoff_required  \
# 0     False     False                119           True        False                         True
# 0     False     False                296           True        False                         True
# 0     False     False                296           True        False                         True
# 0     False     False                139           True        False                         True
# 0     False     False                121           True        False                         True
#
#                                               topics visibility  forks  open_issues  watchers default_branch  network_count  subscribers_count  \
# 0  [3d-graphics, computer-graphics, materialx, ph...     public    308          119      1590           main            308                 85
# 0                                      [opencolorio]     public    404          296      1603           main            404                117
# 0                                      [opencolorio]     public    404          296      1603           main            404                117
# 0  [academy, hdr, image-processing, images, opene...     public    574          139      1504           main            574                132
# 0  [c-plus-plus, dreamworks, fx, openvdb, openvdb...     public    593          121      2267         master            593                146
#
#                  owner.login  owner.id                     owner.node_id                                   owner.avatar_url owner.gravatar_id  \
# 0  AcademySoftwareFoundation  40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy  https://avatars.githubusercontent.com/u/408076...
# 0  AcademySoftwareFoundation  40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy  https://avatars.githubusercontent.com/u/408076...
# 0  AcademySoftwareFoundation  40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy  https://avatars.githubusercontent.com/u/408076...
# 0  AcademySoftwareFoundation  40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy  https://avatars.githubusercontent.com/u/408076...
# 0  AcademySoftwareFoundation  40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy  https://avatars.githubusercontent.com/u/408076...
#
#                                            owner.url                                owner.html_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://github.com/AcademySoftwareFoundation
# 0  https://api.github.com/users/AcademySoftwareFo...  https://github.com/AcademySoftwareFoundation
# 0  https://api.github.com/users/AcademySoftwareFo...  https://github.com/AcademySoftwareFoundation
# 0  https://api.github.com/users/AcademySoftwareFo...  https://github.com/AcademySoftwareFoundation
# 0  https://api.github.com/users/AcademySoftwareFo...  https://github.com/AcademySoftwareFoundation
#
#                                  owner.followers_url                                owner.following_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                                      owner.gists_url                                  owner.starred_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                              owner.subscriptions_url                            owner.organizations_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                                      owner.repos_url                                   owner.events_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                            owner.received_events_url    owner.type  owner.site_admin   license.key                             license.name  \
# 0  https://api.github.com/users/AcademySoftwareFo...  Organization             False    apache-2.0                       Apache License 2.0
# 0  https://api.github.com/users/AcademySoftwareFo...  Organization             False  bsd-3-clause  BSD 3-Clause "New" or "Revised" License
# 0  https://api.github.com/users/AcademySoftwareFo...  Organization             False  bsd-3-clause  BSD 3-Clause "New" or "Revised" License
# 0  https://api.github.com/users/AcademySoftwareFo...  Organization             False  bsd-3-clause  BSD 3-Clause "New" or "Revised" License
# 0  https://api.github.com/users/AcademySoftwareFo...  Organization             False       mpl-2.0               Mozilla Public License 2.0
#
#   license.spdx_id                                   license.url   license.node_id  permissions.admin  permissions.maintain  permissions.push  \
# 0      Apache-2.0    https://api.github.com/licenses/apache-2.0  MDc6TGljZW5zZTI=              False                 False             False
# 0    BSD-3-Clause  https://api.github.com/licenses/bsd-3-clause  MDc6TGljZW5zZTU=              False                 False             False
# 0    BSD-3-Clause  https://api.github.com/licenses/bsd-3-clause  MDc6TGljZW5zZTU=              False                 False             False
# 0    BSD-3-Clause  https://api.github.com/licenses/bsd-3-clause  MDc6TGljZW5zZTU=              False                 False             False
# 0         MPL-2.0       https://api.github.com/licenses/mpl-2.0  MDc6TGljZW5zZTE0              False                 False             False
#
#    permissions.triage  permissions.pull         organization.login  organization.id              organization.node_id  \
# 0               False              True  AcademySoftwareFoundation         40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy
# 0               False              True  AcademySoftwareFoundation         40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy
# 0               False              True  AcademySoftwareFoundation         40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy
# 0               False              True  AcademySoftwareFoundation         40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy
# 0               False              True  AcademySoftwareFoundation         40807682  MDEyOk9yZ2FuaXphdGlvbjQwODA3Njgy
#
#                              organization.avatar_url organization.gravatar_id                                   organization.url  \
# 0  https://avatars.githubusercontent.com/u/408076...                           https://api.github.com/users/AcademySoftwareFo...
# 0  https://avatars.githubusercontent.com/u/408076...                           https://api.github.com/users/AcademySoftwareFo...
# 0  https://avatars.githubusercontent.com/u/408076...                           https://api.github.com/users/AcademySoftwareFo...
# 0  https://avatars.githubusercontent.com/u/408076...                           https://api.github.com/users/AcademySoftwareFo...
# 0  https://avatars.githubusercontent.com/u/408076...                           https://api.github.com/users/AcademySoftwareFo...
#
#                           organization.html_url                         organization.followers_url  \
# 0  https://github.com/AcademySoftwareFoundation  https://api.github.com/users/AcademySoftwareFo...
# 0  https://github.com/AcademySoftwareFoundation  https://api.github.com/users/AcademySoftwareFo...
# 0  https://github.com/AcademySoftwareFoundation  https://api.github.com/users/AcademySoftwareFo...
# 0  https://github.com/AcademySoftwareFoundation  https://api.github.com/users/AcademySoftwareFo...
# 0  https://github.com/AcademySoftwareFoundation  https://api.github.com/users/AcademySoftwareFo...
#
#                           organization.following_url                             organization.gists_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                             organization.starred_url                     organization.subscriptions_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                       organization.organizations_url                             organization.repos_url  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...
#
#                              organization.events_url                   organization.received_events_url organization.type  organization.site_admin  \
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...      Organization                    False
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...      Organization                    False
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...      Organization                    False
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...      Organization                    False
# 0  https://api.github.com/users/AcademySoftwareFo...  https://api.github.com/users/AcademySoftwareFo...      Organization                    False
#
#   license
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN

# %%
repodata.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, 0 to 0
# Data columns (total 126 columns):
#  #    Column                            Non-Null Count  Dtype
# ---   ------                            --------------  -----
#  0    id                                123 non-null    int64
#  1    node_id                           123 non-null    object
#  2    name                              123 non-null    object
#  3    full_name                         123 non-null    object
#  4    private                           123 non-null    bool
#  5    html_url                          123 non-null    object
#  6    description                       121 non-null    object
#  7    fork                              123 non-null    bool
#  8    url                               123 non-null    object
#  9    forks_url                         123 non-null    object
#  10   keys_url                          123 non-null    object
#  11   collaborators_url                 123 non-null    object
#  12   teams_url                         123 non-null    object
#  13   hooks_url                         123 non-null    object
#  14   issue_events_url                  123 non-null    object
#  15   events_url                        123 non-null    object
#  16   assignees_url                     123 non-null    object
#  17   branches_url                      123 non-null    object
#  18   tags_url                          123 non-null    object
#  19   blobs_url                         123 non-null    object
#  20   git_tags_url                      123 non-null    object
#  21   git_refs_url                      123 non-null    object
#  22   trees_url                         123 non-null    object
#  23   statuses_url                      123 non-null    object
#  24   languages_url                     123 non-null    object
#  25   stargazers_url                    123 non-null    object
#  26   contributors_url                  123 non-null    object
#  27   subscribers_url                   123 non-null    object
#  28   subscription_url                  123 non-null    object
#  29   commits_url                       123 non-null    object
#  30   git_commits_url                   123 non-null    object
#  31   comments_url                      123 non-null    object
#  32   issue_comment_url                 123 non-null    object
#  33   contents_url                      123 non-null    object
#  34   compare_url                       123 non-null    object
#  35   merges_url                        123 non-null    object
#  36   archive_url                       123 non-null    object
#  37   downloads_url                     123 non-null    object
#  38   issues_url                        123 non-null    object
#  39   pulls_url                         123 non-null    object
#  40   milestones_url                    123 non-null    object
#  41   notifications_url                 123 non-null    object
#  42   labels_url                        123 non-null    object
#  43   releases_url                      123 non-null    object
#  44   deployments_url                   123 non-null    object
#  45   created_at                        123 non-null    object
#  46   updated_at                        123 non-null    object
#  47   pushed_at                         123 non-null    object
#  48   git_url                           123 non-null    object
#  49   ssh_url                           123 non-null    object
#  50   clone_url                         123 non-null    object
#  51   svn_url                           123 non-null    object
#  52   homepage                          117 non-null    object
#  53   size                              123 non-null    int64
#  54   stargazers_count                  123 non-null    int64
#  55   watchers_count                    123 non-null    int64
#  56   language                          123 non-null    object
#  57   has_issues                        123 non-null    bool
#  58   has_projects                      123 non-null    bool
#  59   has_downloads                     123 non-null    bool
#  60   has_wiki                          123 non-null    bool
#  61   has_pages                         123 non-null    bool
#  62   has_discussions                   123 non-null    bool
#  63   forks_count                       123 non-null    int64
#  64   mirror_url                        1 non-null      object
#  65   archived                          123 non-null    bool
#  66   disabled                          123 non-null    bool
#  67   open_issues_count                 123 non-null    int64
#  68   allow_forking                     123 non-null    bool
#  69   is_template                       123 non-null    bool
#  70   web_commit_signoff_required       123 non-null    bool
#  71   topics                            123 non-null    object
#  72   visibility                        123 non-null    object
#  73   forks                             123 non-null    int64
#  74   open_issues                       123 non-null    int64
#  75   watchers                          123 non-null    int64
#  76   default_branch                    123 non-null    object
#  77   network_count                     123 non-null    int64
#  78   subscribers_count                 123 non-null    int64
#  79   owner.login                       123 non-null    object
#  80   owner.id                          123 non-null    int64
#  81   owner.node_id                     123 non-null    object
#  82   owner.avatar_url                  123 non-null    object
#  83   owner.gravatar_id                 123 non-null    object
#  84   owner.url                         123 non-null    object
#  85   owner.html_url                    123 non-null    object
#  86   owner.followers_url               123 non-null    object
#  87   owner.following_url               123 non-null    object
#  88   owner.gists_url                   123 non-null    object
#  89   owner.starred_url                 123 non-null    object
#  90   owner.subscriptions_url           123 non-null    object
#  91   owner.organizations_url           123 non-null    object
#  92   owner.repos_url                   123 non-null    object
#  93   owner.events_url                  123 non-null    object
#  94   owner.received_events_url         123 non-null    object
#  95   owner.type                        123 non-null    object
#  96   owner.site_admin                  123 non-null    bool
#  97   license.key                       122 non-null    object
#  98   license.name                      122 non-null    object
#  99   license.spdx_id                   122 non-null    object
#  100  license.url                       107 non-null    object
#  101  license.node_id                   122 non-null    object
#  102  permissions.admin                 123 non-null    bool
#  103  permissions.maintain              123 non-null    bool
#  104  permissions.push                  123 non-null    bool
#  105  permissions.triage                123 non-null    bool
#  106  permissions.pull                  123 non-null    bool
#  107  organization.login                123 non-null    object
#  108  organization.id                   123 non-null    int64
#  109  organization.node_id              123 non-null    object
#  110  organization.avatar_url           123 non-null    object
#  111  organization.gravatar_id          123 non-null    object
#  112  organization.url                  123 non-null    object
#  113  organization.html_url             123 non-null    object
#  114  organization.followers_url        123 non-null    object
#  115  organization.following_url        123 non-null    object
#  116  organization.gists_url            123 non-null    object
#  117  organization.starred_url          123 non-null    object
#  118  organization.subscriptions_url    123 non-null    object
#  119  organization.organizations_url    123 non-null    object
#  120  organization.repos_url            123 non-null    object
#  121  organization.events_url           123 non-null    object
#  122  organization.received_events_url  123 non-null    object
#  123  organization.type                 123 non-null    object
#  124  organization.site_admin           123 non-null    bool
#  125  license                           0 non-null      object
# dtypes: bool(20), int64(13), object(93)
# memory usage: 109.3+ KB

# %%
lang_report = repodata.groupby('language').agg({'name': 'count', 
                                                'stargazers_count': 'sum', 
                                                'forks_count': 'sum', 
                                                'open_issues_count': 'sum'})
repo_report = repodata[['full_name', 'name', 'homepage', 'topics', 'forks_count', 'stargazers_count', 'open_issues_count', 'description']].copy()
display(lang_report)
display(repo_report)
# Out:
#                   name  stargazers_count  forks_count  open_issues_count
# language
# C                   12             25471         8228                444
# C++                 14            168235        27810              16421
# Go                  18            350987        81038              10821
# HTML                 5             19325         5229                741
# Java                28            232023       102158              15625
# JavaScript           5             15849         3178               1625
# Jupyter Notebook     1               434           43                  5
# Mathematica          1               686          185                236
# Objective-C          1              5568         1173                287
# Python              11            143107        38839              18033
# Rust                 3             15375         1921               1630
# Scala                6             53457        33177               1278
# Shell                1              9042         1225                147
# Swift               13             27165         3577               1386
# TypeScript           4            208561        55635               8774
#                                    full_name                            name                                           homepage  \
# 0        AcademySoftwareFoundation/MaterialX                       MaterialX                          http://www.materialx.org/
# 0      AcademySoftwareFoundation/OpenColorIO                     OpenColorIO                            https://opencolorio.org
# 0      AcademySoftwareFoundation/OpenColorIO                     OpenColorIO                            https://opencolorio.org
# 0          AcademySoftwareFoundation/openexr                         openexr                            http://www.openexr.com/
# 0          AcademySoftwareFoundation/openvdb                         openvdb                            http://www.openvdb.org/
# 0              AcademySoftwareFoundation/rez                             rez                         https://rez.readthedocs.io
# 0                             apache/airflow                         airflow                        https://airflow.apache.org/
# 0                               apache/arrow                           arrow                          https://arrow.apache.org/
# 0                           apache/cassandra                       cassandra                        http://cassandra.apache.org
# 0                          apache/cloudstack                      cloudstack                     https://cloudstack.apache.org/
# 0                               apache/druid                           druid                          https://druid.apache.org/
# 0                               apache/flink                           flink
# 0                               apache/flume                           flume
# 0                              apache/hadoop                          hadoop                         https://hadoop.apache.org/
# 0                               apache/hbase                           hbase                          https://hbase.apache.org/
# 0                                apache/hive                            hive                           https://hive.apache.org/
# 0                             apache/iceberg                         iceberg                        https://iceberg.apache.org/
# 0                     apache/incubator-toree                 incubator-toree                                               None
# 0                               apache/kafka                           kafka                                               None
# 0                              apache/kyuubi                          kyuubi                         https://kyuubi.apache.org/
# 0                      apache/logging-log4j2                  logging-log4j2              https://logging.apache.org/log4j/2.x/
# 0                              apache/lucene                          lucene                         https://lucene.apache.org/
# 0                                 apache/orc                             orc                            https://orc.apache.org/
# 0                               apache/ozone                           ozone                           https://ozone.apache.org
# 0                          apache/parquet-mr                      parquet-mr
# 0                                apache/solr                            solr                           https://solr.apache.org/
# 0                               apache/spark                           spark                          https://spark.apache.org/
# 0                            apache/superset                        superset                       https://superset.apache.org/
# 0                       apache/trafficserver                   trafficserver                  https://trafficserver.apache.org/
# 0                       apache/yunikorn-core                   yunikorn-core                       https://yunikorn.apache.org/
# 0                           apache/zookeeper                       zookeeper                       https://zookeeper.apache.org
# 0       apple/app-store-server-library-swift  app-store-server-library-swift                                               None
# 0             apple/batch-processing-gateway        batch-processing-gateway
# 0                          apple/coremltools                     coremltools                      https://coremltools.readme.io
# 0                   apple/darwin-libplatform              darwin-libplatform                      https://opensource.apple.com/
# 0                           apple/FHIRModels                      FHIRModels
# 0                         apple/foundationdb                    foundationdb              https://apple.github.io/foundationdb/
# 0                                 apple/GCGC                            GCGC                                               None
# 0           apple/password-manager-resources      password-manager-resources
# 0                          apple/servicetalk                     servicetalk                        https://docs.servicetalk.io
# 0                                apple/swift                           swift                                  https://swift.org
# 0            apple/swift-corelibs-foundation       swift-corelibs-foundation                                          swift.org
# 0           apple/swift-corelibs-libdispatch      swift-corelibs-libdispatch                                          swift.org
# 0                         apple/swift-crypto                    swift-crypto               https://apple.github.io/swift-crypto
# 0             apple/swift-distributed-actors        swift-distributed-actors  https://apple.github.io/swift-distributed-actors/
# 0            apple/swift-distributed-tracing       swift-distributed-tracing  https://swiftpackageindex.com/apple/swift-dist...
# 0                            apple/swift-log                       swift-log                 https://apple.github.io/swift-log/
# 0                        apple/swift-metrics                   swift-metrics             https://apple.github.io/swift-metrics/
# 0                            apple/swift-nio                       swift-nio  https://swiftpackageindex.com/apple/swift-nio/...
# 0                       apple/swift-protobuf                  swift-protobuf
# 0              apple/swift-service-discovery         swift-service-discovery
# 0                           apple/turicreate                      turicreate
# 0                          Autodesk/maya-usd                        maya-usd
# 0                              aws/karpenter                       karpenter                               https://karpenter.sh
# 0                           bazelbuild/bazel                           bazel                                https://bazel.build
# 0                          benchopt/benchopt                        benchopt                         https://benchopt.github.io
# 0                             boostorg/boost                           boost  https://github.com/boostorg/wiki/wiki/Getting-...
# 0                             boostorg/boost                           boost  https://github.com/boostorg/wiki/wiki/Getting-...
# 0                          buildbot/buildbot                        buildbot                           https://www.buildbot.net
# 0                      carekit-apple/CareKit                         CareKit                    https://www.researchandcare.org
# 0                              cilium/cilium                          cilium                                  https://cilium.io
# 0          cloud-hypervisor/cloud-hypervisor                cloud-hypervisor                    https://www.cloudhypervisor.org
# 0                          cloudflare/quiche                          quiche                     https://docs.quic.tech/quiche/
# 0                      containerd/containerd                      containerd                              https://containerd.io
# 0                      crossplane/crossplane                      crossplane                              https://crossplane.io
# 0                       datastax/java-driver                     java-driver                                               None
# 0            DefinitelyTyped/DefinitelyTyped                 DefinitelyTyped
# 0                             delta-io/delta                           delta                                   https://delta.io
# 0                      dropwizard/dropwizard                      dropwizard                          https://www.dropwizard.io
# 0                             elyra-ai/elyra                           elyra            https://elyra.readthedocs.io/en/stable/
# 0                           envoyproxy/envoy                           envoy                          https://www.envoyproxy.io
# 0                               etcd-io/etcd                            etcd                                    https://etcd.io
# 0                        falcosecurity/falco                           falco                                  https://falco.org
# 0                              filodb/FiloDB                          FiloDB
# 0                              GNOME/libxml2                         libxml2             https://gitlab.gnome.org/GNOME/libxml2
# 0                              GNOME/libxslt                         libxslt             https://gitlab.gnome.org/GNOME/libxslt
# 0                               google/angle                           angle                            http://angleproject.org
# 0                           google/boringssl                       boringssl       https://boringssl.googlesource.com/boringssl
# 0               google/data-transfer-project           data-transfer-project                     http://datatransferproject.dev
# 0                                 google/jax                             jax                         http://jax.readthedocs.io/
# 0  GoogleCloudPlatform/spark-on-k8s-operator           spark-on-k8s-operator
# 0                              goss-org/goss                            goss                                 https://goss.rocks
# 0                              goss-org/goss                            goss                                 https://goss.rocks
# 0                            grpc/grpc-swift                      grpc-swift
# 0                     hotosm/tasking-manager                 tasking-manager  https://wiki.openstreetmap.org/wiki/Tasking_Ma...
# 0                     hotosm/tasking-manager                 tasking-manager  https://wiki.openstreetmap.org/wiki/Tasking_Ma...
# 0                                istio/istio                           istio                                   https://istio.io
# 0                  cert-manager/cert-manager                    cert-manager                            https://cert-manager.io
# 0                  cert-manager/cert-manager                    cert-manager                            https://cert-manager.io
# 0          jupyter-server/enterprise_gateway              enterprise_gateway  https://jupyter-enterprise-gateway.readthedocs...
# 0            kata-containers/kata-containers                 kata-containers
# 0                          kubeflow/kubeflow                        kubeflow
# 0                      kubernetes/kubernetes                      kubernetes                              https://kubernetes.io
# 0                          kubevirt/kubevirt                        kubevirt                                https://kubevirt.io
# 0                                lzfse/lzfse                           lzfse
# 0                              machyve/xhyve                           xhyve
# 0            maproulette/maproulette-backend             maproulette-backend
# 0                       microsoft/TypeScript                      TypeScript                     https://www.typescriptlang.org
# 0                        multipath-tcp/mptcp                           mptcp                          https://multipath-tcp.org
# 0                                netty/netty                           netty                                    http://netty.io
# 0                      open-policy-agent/opa                             opa                    https://www.openpolicyagent.org
# 0            open-telemetry/opentelemetry.io                opentelemetry.io                           https://opentelemetry.io
# 0                               osmlab/atlas                           atlas                                               None
# 0                            osquery/osquery                         osquery                                 https://osquery.io
# 0              PixarAnimationStudios/OpenUSD                         OpenUSD                             http://www.openusd.org
# 0                playframework/playframework                   playframework                       http://www.playframework.com
# 0                      prometheus/prometheus                      prometheus                             https://prometheus.io/
# 0                              pulumi/pulumi                          pulumi                             https://www.pulumi.com
# 0                            pytorch/pytorch                         pytorch                                https://pytorch.org
# 0                                  qemu/qemu                            qemu                                http://www.qemu.org
# 0                    ResearchKit/ResearchKit                     ResearchKit                    https://www.researchandcare.org
# 0                             scverse/scanpy                          scanpy                      https://scanpy.readthedocs.io
# 0                        SeleniumHQ/selenium                        selenium                               https://selenium.dev
# 0                        spinnaker/spinnaker                       spinnaker                           http://www.spinnaker.io/
# 0             strimzi/strimzi-kafka-operator          strimzi-kafka-operator                                https://strimzi.io/
# 0      swift-server/swift-aws-lambda-runtime        swift-aws-lambda-runtime
# 0               swift-server/swift-backtrace                 swift-backtrace
# 0               swift-server/swift-backtrace                 swift-backtrace
# 0                        temporalio/temporal                        temporal                           https://docs.temporal.io
# 0                            theislab/moscot                          moscot                           https://moscot-tools.org
# 0                              trinodb/trino                           trino                                   https://trino.io
# 0                  uber/RemoteShuffleService            RemoteShuffleService
# 0                                  vega/vega                            vega                        https://vega.github.io/vega
#
#                                               topics  forks_count  stargazers_count  open_issues_count  \
# 0  [3d-graphics, computer-graphics, materialx, ph...          308              1590                119
# 0                                      [opencolorio]          404              1603                296
# 0                                      [opencolorio]          404              1603                296
# 0  [academy, hdr, image-processing, images, opene...          574              1504                139
# 0  [c-plus-plus, dreamworks, fx, openvdb, openvdb...          593              2267                121
# 0  [environment-configuration, multi-platform, pa...          297               842                340
# 0  [airflow, apache, apache-airflow, python, sche...        13057             32200                932
# 0                                            [arrow]         3101             12662               3936
# 0                        [cassandra, database, java]         3499              8245                381
# 0  [cloud, cloudstack, iaas, infrastructure, java...         1029              1535                391
# 0                                            [druid]         3618             12920               1327
# 0        [big-data, flink, java, python, scala, sql]        12835             22137               1078
# 0                            [big-data, flume, java]         1585              2458                 91
# 0                                           [hadoop]         8638             13926                933
# 0                            [database, hbase, java]         3278              4993                191
# 0  [apache, big-data, database, hadoop, hive, jav...         4541              5119                101
# 0                   [apache, hacktoberfest, iceberg]         1810              4875               1476
# 0                                            [toree]          227               722                 15
# 0                                     [kafka, scala]        13156             26099               1086
# 0  [data-lake, hacktoberfest, hadoop, hive, jdbc,...          725              1754                437
# 0  [apache, api, java, jvm, library, log4j, log4j...         1551              3175                 75
# 0  [backend, information-retrieval, java, lucene,...          836              2033               2205
# 0                 [apache, big-data, cpp, java, orc]          477               630                 32
# 0  [big-data, hadoop, kubernetes, object-store, s...          459               702                 91
# 0                          [big-data, java, parquet]         1338              2196                132
# 0  [backend, information-retrieval, java, lucene,...          546               878                187
# 0  [big-data, java, jdbc, python, r, scala, spark...        27833             37069                222
# 0  [analytics, apache, apache-superset, asf, bi, ...        11535             54968               1586
# 0  [apache, cache, cdn, forwardproxy, hacktoberfe...          785              1655                402
# 0  [apache-yarn, go, kubernetes, universal-resour...          187               685                 12
# 0  [apache, configuration-management, consensus, ...         7118             11600                235
# 0                                                 []            6               128                  3
# 0         [batch-processing, k8s, kubernetes, spark]           33               150                  3
# 0  [coreml, coremltools, machine-learning, model-...          563              3696                270
# 0                                                 []           51               127                  0
# 0               [fhir, swift, swift-package-manager]           32               153                  6
# 0  [acid, distributed-database, foundationdb, key...         1278             13339                875
# 0                                                 []           43               434                  5
# 0                                                 []          429              3849                 99
# 0  [framework, grpc, http, http2, java, microserv...          164               856                 77
# 0                                                 []        10335             64355               6819
# 0                                                 []         1132              5093                692
# 0                                                 []          457              2364                 77
# 0  [boringssl, ciphers, cryptography, ecdh, ecdsa...          136              1351                 22
# 0  [actor-model, actors, distributed-systems, swift]           49               538                156
# 0  [distributed-systems, distributed-tracing, swi...           21               173                  9
# 0                            [logging, swift-server]          252              3158                 26
# 0                            [metrics, swift-server]           55               587                 21
# 0  [asynchronous-io, event-driven, high-performan...          627              7553                204
# 0                                                 []          443              4324                 58
# 0                                                 []           16               200                  3
# 0          [deep-learning, machine-learning, python]         1155             11098                519
# 0                                                 []          185               686                236
# 0                                                 []          661              5025                265
# 0  [bazel, build, build-system, correct, fast, mu...         3893             21527               1862
# 0  [benchmark, julia-language, machine-learning, ...           49               192                113
# 0                                                 []         1629              6101                103
# 0                                                 []         1629              6101                103
# 0  [ci, ci-framework, continuous-integration, pyt...         1649              5093                726
# 0  [carekit, combine, core-data, darkmode-ios13, ...          453              2333                 85
# 0  [bpf, cncf, cni, containers, ebpf, k8s, kernel...         2450             16815               1105
# 0   [cloud-workloads, kvm, rust-vmm, virtualization]          376              3064                 67
# 0  [http3, network-programming, protocol, quic, r...          626              8235                201
# 0  [cncf, containerd, containers, cri, docker, ha...         3131             15028                673
# 0  [cloud-computing, cloud-native, containers, ku...          806              7684                196
# 0                                                 []          871              1313                 26
# 0  [definition, dts, hacktoberfest, types, typesc...        29595             45596                889
# 0     [acid, analytics, big-data, delta-lake, spark]         1452              6440                503
# 0  [dropwizard, hibernate, java, jax-rs, jdbi, je...         3475              8423                 14
# 0  [ai, airflow, anaconda, apache-airflow, binder...          307              1680                270
# 0  [cars, cats, cats-over-dogs, cncf, corgis, mor...         4498             22920               1598
# 0  [cncf, consensus, database, distributed-databa...         9531             44767                245
# 0  [cloud-native, cncf, cncf-project, containers,...          831              6405                 91
# 0  [database, distributed, kafka, metrics, promet...          227              1409                 36
# 0                                                 []          339               489                  0
# 0                                                 []           42                53                  0
# 0                                                 []          551              3050                  3
# 0                                                 []          702              1575                  1
# 0    [data, data-portability, portability, transfer]          495              3517                166
# 0                                              [jax]         2367             25121               1692
# 0  [apache-spark, google-cloud-dataproc, kubernet...         1287              2460                520
# 0  [devops, devops-tools, docker, go, golang, gos...          500              5297                 32
# 0  [devops, devops-tools, docker, go, golang, gos...          500              5297                 32
# 0        [grpc, protocol-buffers, swift, swift-grpc]          400              1850                 88
# 0  [flask, javascript, openstreetmap, postgis, po...          254               481                425
# 0  [flask, javascript, openstreetmap, postgis, po...          254               481                425
# 0  [api-management, circuit-breaker, consul, enfo...         7401             33849                565
# 0  [certificate, crd, hacktoberfest, kubernetes, ...         1946             10829                204
# 0  [certificate, crd, hacktoberfest, kubernetes, ...         1946             10829                204
# 0  [enterprise, gateway, hacktoberfest, jupyter, ...          210               576                 74
# 0  [acrn, containers, cri, cri-o, docker, firecra...          919              4076               1362
# 0  [google-kubernetes-engine, jupyter, kubeflow, ...         2227             13082                366
# 0                 [cncf, containers, go, kubernetes]        38182            102526               2805
# 0  [hacktoberfest, kubernetes, libvirt, virtualiz...         1100              4637                323
# 0                                                 []          184              1730                 28
# 0                                                 []          371              6407                 90
# 0                  [maproulette, openstreetmap, osm]           36                47                118
# 0    [javascript, language, typechecker, typescript]        12278             94915               5933
# 0                                                 []          334               868                 71
# 0                                                 []        15630             31988                589
# 0  [authorization, cloud-native, compliance, decl...         1194              8591                319
# 0                     [documentation, opentelemetry]          753               414                228
# 0  [atlas, geospatial, geospatial-data, geospatia...           77               221                 18
# 0  [hacktoberfest, intrusion-detection, monitorin...         2489             20699                595
# 0                                                 []         1078              4989                751
# 0  [framework, hacktoberfest, java, jvm, play, pl...         4129             12456                450
# 0  [alerting, graphing, hacktoberfest, metrics, m...         8578             50391                918
# 0  [aws, azure, cloud, cloud-computing, container...          992             17950               2012
# 0  [autograd, deep-learning, gpu, machine-learnin...        19795             72016              13035
# 0                  [emulation, qemu, virtualization]         5016              8480                  0
# 0                                                 []         1173              5568                287
# 0  [anndata, bioinformatics, data-science, machin...          539              1623                546
# 0  [dotnet, java, javascript, python, ruby, selen...         7859             28056                262
# 0  [continuous-delivery, continuous-deployment, s...         1225              9042                147
# 0  [data-stream, data-streaming, data-streams, do...         1172              4083                140
# 0                                                 []           91              1075                 35
# 0                                                 []           32               288                  8
# 0                                                 []           32               288                  8
# 0  [cronjob-scheduler, distributed-cron, distribu...          646              8327                391
# 0                   [optimal-transport, single-cell]            6                68                 35
# 0  [analytics, big-data, data-science, database, ...         2556              8715               2457
# 0                                                 []           96               283                 31
# 0  [canvas, d3, svg, vega, visualization, visuali...         1488             10624                448
#
#                                          description
# 0  MaterialX is an open standard for the exchange...
# 0  A color management framework for visual effect...
# 0  A color management framework for visual effect...
# 0  The OpenEXR project provides the specification...
# 0   OpenVDB - Sparse volume data structure and tools
# 0  An integrated package configuration, build and...
# 0  Apache Airflow - A platform to programmaticall...
# 0  Apache Arrow is a multi-language toolbox for a...
# 0                         Mirror of Apache Cassandra
# 0  Apache CloudStack is an opensource Infrastruct...
# 0  Apache Druid: a high performance real-time ana...
# 0                                       Apache Flink
# 0                             Mirror of Apache Flume
# 0                                      Apache Hadoop
# 0                                       Apache HBase
# 0                                        Apache Hive
# 0                                     Apache Iceberg
# 0                Mirror of Apache Toree (Incubating)
# 0                             Mirror of Apache Kafka
# 0  Apache Kyuubi is a distributed and multi-tenan...
# 0  Apache Log4j 2 is a versatile, feature-rich, e...
# 0          Apache Lucene open-source search software
# 0  Apache ORC - the smallest, fastest columnar st...
# 0  Scalable, redundant, and distributed object st...
# 0                                     Apache Parquet
# 0            Apache Solr open-source search software
# 0  Apache Spark - A unified analytics engine for ...
# 0  Apache Superset is a Data Visualization and Da...
# 0  Apache Traffic Server™ is a fast, scalable and...
# 0                               Apache YuniKorn Core
# 0                                   Apache ZooKeeper
# 0                                               None
# 0  The gateway component to make Spark on K8s muc...
# 0  Core ML tools contain supporting tools for Cor...
# 0  Legacy mirror of  Darwin Platform Library. Rep...
# 0       Swift library for FHIR® resource data models
# 0  FoundationDB - the open source, distributed, t...
# 0                                               None
# 0  A place for creators and users of password man...
# 0  A networking framework that evolves with your ...
# 0                     The Swift Programming Language
# 0  The Foundation Project, providing core utiliti...
# 0  The libdispatch Project, (a.k.a. Grand Central...
# 0  Open-source implementation of a substantial po...
# 0  Peer-to-peer cluster implementation for Swift ...
# 0  Instrumentation library for Swift server appli...
# 0                            A Logging API for Swift
# 0                              Metrics API for Swift
# 0  Event-driven network application framework for...
# 0  Plugin and runtime library for using protobuf ...
# 0                 A service discovery API for Swift.
# 0  Turi Create simplifies the development of cust...
# 0  A common USD (Universal Scene Description) plu...
# 0  Karpenter is a Kubernetes Node Autoscaler buil...
# 0  a fast, scalable, multi-language and extensibl...
# 0  Making your benchmark of optimization algorith...
# 0                Super-project for modularized Boost
# 0                Super-project for modularized Boost
# 0  Python-based continuous integration testing fr...
# 0  CareKit is an open source software framework f...
# 0  eBPF-based Networking, Security, and Observabi...
# 0  A Virtual Machine Monitor for modern Cloud wor...
# 0  🥧 Savoury implementation of the QUIC transport...
# 0             An open and reliable container runtime
# 0                        Cloud Native Control Planes
# 0          DataStax Java Driver for Apache Cassandra
# 0  The repository for high quality TypeScript typ...
# 0  An open-source storage framework that enables ...
# 0  A damn simple library for building production-...
# 0  Elyra extends JupyterLab with an AI centric ap...
# 0  Cloud-native high-performance edge/middle/serv...
# 0  Distributed reliable key-value store for the m...
# 0                      Cloud Native Runtime Security
# 0        Distributed Prometheus time series database
# 0  Read-only mirror of https://gitlab.gnome.org/G...
# 0  Read-only mirror of https://gitlab.gnome.org/G...
# 0  A conformant OpenGL ES implementation for Wind...
# 0                                Mirror of BoringSSL
# 0  The Data Transfer Project makes it easy for pe...
# 0  Composable transformations of Python+NumPy pro...
# 0  Kubernetes operator for managing the lifecycle...
# 0           Quick and Easy server testing/validation
# 0           Quick and Easy server testing/validation
# 0         The Swift language implementation of gRPC.
# 0  Tasking Manager - The tool to team up for mapp...
# 0  Tasking Manager - The tool to team up for mapp...
# 0    Connect, secure, control, and observe services.
# 0  Automatically provision and manage TLS certifi...
# 0  Automatically provision and manage TLS certifi...
# 0  A lightweight, multi-tenant, scalable and secu...
# 0  Kata Containers is an open source project and ...
# 0            Machine Learning Toolkit for Kubernetes
# 0  Production-Grade Container Scheduling and Mana...
# 0  Kubernetes Virtualization API and runtime in o...
# 0    LZFSE compression library and command line tool
# 0  xhyve, a lightweight OS X virtualization solution
# 0                         MapRoulette back-end / API
# 0  TypeScript is a superset of JavaScript that co...
# 0  Out-of-tree Linux Kernel implementation of Mul...
# 0  Netty project - an event-driven asynchronous n...
# 0  Open Policy Agent (OPA) is an open source, gen...
# 0        The OpenTelemetry website and documentation
# 0                                      OSM in memory
# 0  SQL powered operating system instrumentation, ...
# 0                        Universal Scene Description
# 0                                     Play Framework
# 0  The Prometheus monitoring system and time seri...
# 0  Pulumi - Infrastructure as Code in any program...
# 0  Tensors and Dynamic neural networks in Python ...
# 0  Official QEMU mirror. Please see https://www.q...
# 0  ResearchKit is an open source software framewo...
# 0  Single-cell analysis in Python. Scales to >1M ...
# 0      A browser automation framework and ecosystem.
# 0  Spinnaker is an open source, multi-cloud conti...
# 0                Apache Kafka® running on Kubernetes
# 0         Swift implementation of AWS Lambda Runtime
# 0        💥 Backtraces for Swift on Linux and Windows
# 0        💥 Backtraces for Swift on Linux and Windows
# 0                                   Temporal service
# 0     Multi-omic single-cell optimal transport tools
# 0  Official repository of Trino, the distributed ...
# 0  Remote shuffle service for Apache Spark to sto...
# 0                           A visualization grammar.

# %%
repo_report.to_csv('out/osrb-repo-report.csv', index=False)
repo_report.to_json('out/osrb-repo-report.json', orient='records', lines=True)

lang_report.to_csv('out/osrb-lang-report.csv')
